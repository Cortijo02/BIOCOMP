# %% [markdown]
# # TSP

# %%
import random
N = 100

cities = []

for i in range(N):
	c = [random.random(), random.random()]
	cities.append(c)

#print(cities)

cities = [[0.8744058793117488, 0.30207179832703746], [0.6901572276474558, 0.8203362566663311], [0.7793458478083026, 0.09728979746351918], [0.7483358474304422, 0.4563419482458657], [0.4556164527790729, 0.12863149772605698], [0.1837236688553453, 0.23773749495644914], [0.806151832654163, 0.3288366900529254], [0.6222702185205219, 0.6019431085670109], [0.21886861543988367, 0.6980104036528004], [0.9706096813038716, 0.054871876245520146], [0.13881496219356027, 0.048489530185603646], [0.08511086492841424, 0.9123075505436051], [0.45436952164297595, 0.4731540740573398], [0.8986352255038935, 0.5116579750591849], [0.9539248970461742, 0.7530784036308166], [0.6321102985156373, 0.13575967095580344], [0.31130918313591205, 0.8545457319320597], [0.025897479791937017, 0.7854526665590987], [0.31414095045738066, 0.051421702103483846], [0.2739561013272712, 0.1970964027924862], [0.22762328443470214, 0.627414210742153], [0.44920042912037383, 0.18835427573438068], [0.2793138301174244, 0.9103956650199608], [0.005128451667189338, 0.4655718085045638], [0.9222718335261915, 0.8613103704784812], [0.49352498279326595, 0.28652416807644077], [0.5560886356057152, 0.034564925228364185], [0.0048939219846825255, 0.8635350555457212], [0.7824462381771976, 0.09355415747424733], [0.2973635133076785, 0.037580527218207815], [0.659068210692151, 0.5602321147981546], [0.43549418718677035, 0.6241289474799954], [0.25580657871099755, 0.519726015381631], [0.5950780852425872, 0.3193476592023645], [0.15763623266223903, 0.18210618406479095], [0.3434173147566393, 0.32992255868483356], [0.06451313705472006, 0.12606114349173192], [0.23212286400737547, 0.3945559700824013], [0.955507285594692, 0.02296933408938162], [0.7459955912073274, 0.1385374827130177], [0.46365765315595475, 0.6132297411379687], [0.20196772698059162, 0.046358747430397584], [0.2980093518214506, 0.36041197123227897], [0.7533459401199348, 0.6610562232191091], [0.323433933838161, 0.5068337090138902], [0.062138830138457, 0.7177455044259695], [0.47467832142010535, 0.17692718986260936], [0.2415634321550142, 0.500852093941769], [0.3441878827094532, 0.2604351258948506], [0.5445252142594251, 0.7295590645635646], [0.25391391610860914, 0.7641244059389684], [0.2630560480211699, 0.010670642241309536], [0.2092202940037915, 0.7415775443241935], [0.0031474687633804566, 0.6974574785842637], [0.4952329615559806, 0.9311775894780175], [0.1978488658972426, 0.8872693649066419], [0.1705364411799497, 0.8846808176103278], [0.7634962513234275, 0.4358457309207533], [0.9259752834140167, 0.0056226911773098465], [0.22090405091557253, 0.14500040130773872], [0.4636205151855679, 0.19249574424477278], [0.8057632881682811, 0.250168118157608], [0.6785236695642043, 0.39119477830554505], [0.4837264739606879, 0.23045417711558214], [0.8786721718893166, 0.015853186240832207], [0.1263309724872509, 0.9185321014517236], [0.24969404380600335, 0.9600467657522086], [0.5886119367943214, 0.10948123668473264], [0.13373527735293878, 0.5336853876899833], [0.5642696742735989, 0.9801384844337597], [0.646401605512568, 0.3338636388089157], [0.05603526365085032, 0.3149530712641142], [0.387141492676661, 0.5792852545912592], [0.8634070619751958, 0.8206820685065667], [0.4662474858565825, 0.32647667516764145], [0.01801973379815025, 0.12175434785651695], [0.6218125565554127, 0.07860046445444713], [0.6573938922925594, 0.5023092428939168], [0.2837581848186974, 0.02576704782244421], [0.3044774374252185, 0.7310313422019327], [0.33131673439274434, 0.693896434962478], [0.8523694048117944, 0.2805224723356823], [0.6200019812032047, 0.03989814578273998], [0.5437394088109648, 0.3258031129949792], [0.4386079860370994, 0.6142798815693052], [0.7430581106897977, 0.49260737229959284], [0.3913628378102181, 0.3185830750836698], [0.9065498976196814, 0.02381958527497441], [0.6874236611131453, 0.18642068590773597], [0.6946411585627993, 0.36991609629423117], [0.3784063098306413, 0.01018756575849844], [0.43806374889930155, 0.2268325586117821], [0.7411632641820634, 0.35513151640087337], [0.3884706603234591, 0.34043302784114093], [0.08674110453583683, 0.4491174987265194], [0.9794883193315694, 0.11207520940235804], [0.7496156619797683, 0.23845386610980834], [0.4423888847621813, 0.17212722421686055], [0.2276570035864689, 0.6515924491551327], [0.836939257954547, 0.0499933914625984]] # Length=8.587

def dist (x, y): # distancia euclídea
	return ( (x[0]-y[0])**2 + (x[1]-y[1])**2 ) ** 0.5

def globaldist (cities): # calcula la ditancia global de una solución
	acum = 0.0
	for i in range(len(cities)):
		acum += dist(cities[i-1],cities[i]) # -1 is the last element
	return acum

def fit_cities (cities): # fitness para TSP
	return 1 / (1+globaldist(cities))

# %%
# draw a TSP solution

import matplotlib.pyplot as plt
import numpy as np

def draw (solution):
    plt.ion()
    fig = plt.figure()
    axes = fig.add_subplot(111)
    xlim = axes.set_xlim(0.0,1.0)
    ylim = axes.set_ylim(0.0,1.0)
    x = []
    y = []

    bucle = solution + [solution[0]] # añade al final la vuelta a la primera

    c = np.array(bucle)
    x = c[:,0]
    y = c[:,1]

    l1, = axes.plot(x, y,'g')
    l2, = axes.plot(x, y,'ro')

    s = 'Length=%5.3f' % globaldist(bucle)
    plt.title(s)

draw(cities)

# %% [markdown]
# ## Estudio de parámetros y funciones

# %% [markdown]
# ### Experimento 1: Algoritmo Genético básico

# %% [markdown]
# #### Operaciones básicas

# %% [markdown]
# Se implementan los componentes básicos de inicialización, evaluación y selección del Algoritmo Genético aplicado al TSP. La población inicial se genera de forma aleatoria, donde cada individuo es una permutación del conjunto de ciudades, garantizando diversidad desde la primera generación. Posteriormente, la población se evalúa mediante una función de fitness y se ordena según un criterio de minimización, de manera que los mejores individuos ocupan las primeras posiciones. Sobre esta población ordenada se aplica un mecanismo de selección por torneo, en el que se eligen varios individuos al azar y se selecciona el mejor de ellos, introduciendo presión selectiva sin perder diversidad y asegurando que los individuos seleccionados sean copias independientes

# %%
import random
import copy

def create (alphabet, N=100): # crea y devuelve población
    # Cada individuo es una permutación del alfabeto (p.ej. lista de ciudades)
    pop = []
    for _ in range(N):
        ind = list(alphabet)         # copia
        random.shuffle(ind)          # permutación
        pop.append(ind)
    return pop

def sort_pop(pop, fit):
    fits = [fit(ind) for ind in pop]
    idx = sorted(range(len(pop)), key=lambda i: fits[i])  # minimización
    pop_sorted = [pop[i] for i in idx]
    fits_sorted = [fits[i] for i in idx]
    return pop_sorted, fits_sorted


def select (pop, T): # devuelve un individuo seleccionado por torneo, devuelve una copia para evitar efectos laterales
    # pop se supone ya ordenada por fitness (mejor = pop[0])
    # Torneo: elige T individuos al azar y devuelve el mejor (min fitness)
    best = None
    best_pos = None
    n = len(pop)
    for _ in range(T):
        j = random.randrange(n)
        if (best_pos is None) or (j < best_pos):
            best_pos = j
            best = pop[j]
    return copy.deepcopy(best)

# %% [markdown]
# #### Cruces y mutaciones

# %% [markdown]
# El operador de cruce utilizado en este experimento es **Order Crossover (OX)**, un operador específicamente diseñado para problemas de optimización combinatoria con representación por permutaciones, como el TSP. A diferencia de los cruces clásicos, OX garantiza que los hijos generados sean soluciones factibles, es decir, que cada ciudad aparezca exactamente una vez en la ruta.
#
# El **Partially Mapped Crossover (PMX)** selecciona un segmento de uno de los progenitores y lo copia directamente al descendiente, estableciendo a continuación un mapeo entre los genes intercambiados para completar el resto de la solución sin introducir duplicados. De este modo, el operador preserva información posicional de los padres y garantiza que los individuos generados sean permutaciones válidas.

# %%
def ox_crossover(ind1, ind2, pcross):
    if random.random() > pcross:
        return copy.deepcopy(ind1), copy.deepcopy(ind2)

    L = len(ind1)
    a, b = sorted(random.sample(range(L), 2))

    def key(city):
        return tuple(city) if isinstance(city, list) else city

    def ox(p1, p2):
        child = [None] * L
        child[a:b+1] = copy.deepcopy(p1[a:b+1])
        used = set(key(c) for c in child[a:b+1])

        pos = (b + 1) % L
        for x in p2[b+1:] + p2[:b+1]:
            if key(x) in used:
                continue
            child[pos] = copy.deepcopy(x)
            used.add(key(x))
            pos = (pos + 1) % L

        return child

    return ox(ind1, ind2), ox(ind2, ind1)


def pmx_crossover(ind1, ind2, pcross):
    if random.random() > pcross:
        return copy.deepcopy(ind1), copy.deepcopy(ind2)

    size = len(ind1)
    start, end = sorted(random.sample(range(size), 2))

    child1 = [None] * size
    child2 = [None] * size

    child1[start:end] = copy.deepcopy(ind1[start:end])
    child2[start:end] = copy.deepcopy(ind2[start:end])

    mapping1 = {tuple(ind1[i]): tuple(ind2[i]) for i in range(start, end)}
    mapping2 = {tuple(ind2[i]): tuple(ind1[i]) for i in range(start, end)}

    def fill(child, parent, mapping):
        for i in range(size):
            if child[i] is None:
                gene = tuple(parent[i])
                while gene in mapping:
                    gene = mapping[gene]
                child[i] = list(gene)
        return child

    return fill(child1, ind2, mapping1), fill(child2, ind1, mapping2)

# %% [markdown]
# Se emplea un operador de **swap mutation** (mutate). Conceptualmente, este operador puede interpretarse como una mutación equiprobable por gen, donde cada gen tiene una probabilidad inversamente proporcional a la longitud del cromosoma ($1/L$). La mutación por inversión invierte el orden de un segmento de la ruta, la mutación por mezcla (scramble) reordena aleatoriamente las ciudades de un subsegmento y la mutación aleatoria por permutaciones selecciona de forma estocástica uno de estos operadores

# %%
def mutate (ind, pmut):
    if random.random() > pmut:
        return ind

    L = len(ind)
    i, j = random.sample(range(L), 2)
    ind[i], ind[j] = ind[j], ind[i]
    return ind

def inversion_mutation(ind, pmut):
    if random.random() > pmut:
        return ind
    i, j = sorted(random.sample(range(len(ind)), 2))
    ind[i:j+1] = reversed(ind[i:j+1])
    return ind

def scramble_mutation(ind, pmut):
    if random.random() > pmut:
        return ind
    i, j = sorted(random.sample(range(len(ind)), 2))
    sub = ind[i:j+1]
    random.shuffle(sub)
    ind[i:j+1] = sub
    return ind

def random_perm_mutation(ind, pmut):
    options = [mutate, inversion_mutation, scramble_mutation]
    return random.choice(options)(ind, pmut)

# %% [markdown]
# #### Evaluación
#
# En cada iteración, la población se evalúa y ordena según la función de fitness, se seleccionan individuos mediante torneo y se generan nuevos descendientes aplicando los operadores de cruce y mutación.
#
# La condición de parada del algoritmo se define en términos del número máximo de evaluaciones de la función objetivo $1 M$, tal y como especifica el enunciado. Para ello, se introduce un contador explícito de evaluaciones que se incrementa cada vez que la población es evaluada

# %%
import csv

def evolve(
    pop,
    fit,
    mutation,
    crossover,
    pmut,
    pcross,
    max_evals=1_000_000,
    T=2,
    elitism=False
):
    evals = 0
    gen = 0
    pop_size = len(pop)

    history = []  # (generation, min_fitness)

    while evals < max_evals:
        gen += 1

        pop_sorted, fits_sorted = sort_pop(pop, fit)
        evals += pop_size

        # Guardar mejor fitness de la generación
        history.append((gen, fits_sorted[0]))

        new_pop = []

        if elitism:
            elite = copy.deepcopy(pop_sorted[0])
            new_pop.append(elite)

        while len(new_pop) < pop_size:
            p1 = select(pop_sorted, T)
            p2 = select(pop_sorted, T)

            c1, c2 = crossover(p1, p2, pcross)

            c1 = mutation(c1, pmut)
            new_pop.append(c1)

            if len(new_pop) < pop_size:
                c2 = mutation(c2, pmut)
                new_pop.append(c2)

        pop = new_pop

        # if evals % 1_000 == 0:
        #     print(f"Evals: {evals}, Best fitness: {fits_sorted[0]}")

    pop_sorted, _ = sort_pop(pop, fit)
    return pop_sorted, history

# %% [markdown]
# #### Evolucionamos y pintamos resultados

# %%
mutations = {
    "swap": mutate,
    "inversion": inversion_mutation,
    "scramble": scramble_mutation,
    "random": random_perm_mutation
}

crossovers = {
    "ox": ox_crossover,
    "pmx": pmx_crossover
}

# %% [markdown]
# Se ha tomado la decisión de excluir `"elitism": False` del espacio de búsqueda ya que las pruebas iniciales sugieren que es mejor trabajar con elitismo y añadirlo a la búsqueda incrementa considerablemente el tiempo de ejecución.

# %%
configs = [
    # swap
    {"crossover":"ox", "mutation": "swap", "pmut": 1/100, "pcross": 0.7, "elitism": True, "T": 10},
    {"crossover":"ox", "mutation": "swap", "pmut": 1/100, "pcross": 0.8, "elitism": True, "T": 10},

    {"crossover":"ox", "mutation": "swap", "pmut": 1/100, "pcross": 0.7, "elitism": True, "T": 12},
    {"crossover":"ox", "mutation": "swap", "pmut": 1/100, "pcross": 0.8, "elitism": True, "T": 12},


    {"crossover":"pmx", "mutation": "swap", "pmut": 1/100, "pcross": 0.7, "elitism": True, "T": 10},
    {"crossover":"pmx", "mutation": "swap", "pmut": 1/100, "pcross": 0.8, "elitism": True, "T": 10},

    {"crossover":"pmx", "mutation": "swap", "pmut": 1/100, "pcross": 0.7, "elitism": True, "T": 12},
    {"crossover":"pmx", "mutation": "swap", "pmut": 1/100, "pcross": 0.8, "elitism": True, "T": 12},


    # --------------

    {"crossover":"ox", "mutation": "swap", "pmut": 1/10, "pcross": 0.7, "elitism": True, "T": 10},
    {"crossover":"ox", "mutation": "swap", "pmut": 1/10, "pcross": 0.8, "elitism": True, "T": 10},

    {"crossover":"ox", "mutation": "swap", "pmut": 1/10, "pcross": 0.7, "elitism": True, "T": 12},
    {"crossover":"ox", "mutation": "swap", "pmut": 1/10, "pcross": 0.8, "elitism": True, "T": 12},
    

    {"crossover":"pmx", "mutation": "swap", "pmut": 1/10, "pcross": 0.7, "elitism": True, "T": 10},
    {"crossover":"pmx", "mutation": "swap", "pmut": 1/10, "pcross": 0.8, "elitism": True, "T": 10},

    {"crossover":"pmx", "mutation": "swap", "pmut": 1/10, "pcross": 0.7, "elitism": True, "T": 12},
    {"crossover":"pmx", "mutation": "swap", "pmut": 1/10, "pcross": 0.8, "elitism": True, "T": 12},


    # inversion
    {"crossover":"ox", "mutation": "inversion", "pmut": 1/100, "pcross": 0.7, "elitism": True, "T": 10},
    {"crossover":"ox", "mutation": "inversion", "pmut": 1/100, "pcross": 0.8, "elitism": True, "T": 10},

    {"crossover":"ox", "mutation": "inversion", "pmut": 1/100, "pcross": 0.7, "elitism": True, "T": 12},
    {"crossover":"ox", "mutation": "inversion", "pmut": 1/100, "pcross": 0.8, "elitism": True, "T": 12},


    {"crossover":"pmx", "mutation": "inversion", "pmut": 1/100, "pcross": 0.7, "elitism": True, "T": 10},
    {"crossover":"pmx", "mutation": "inversion", "pmut": 1/100, "pcross": 0.8, "elitism": True, "T": 10},

    {"crossover":"pmx", "mutation": "inversion", "pmut": 1/100, "pcross": 0.7, "elitism": True, "T": 12},
    {"crossover":"pmx", "mutation": "inversion", "pmut": 1/100, "pcross": 0.8, "elitism": True, "T": 12},


    # --------------

    {"crossover":"ox", "mutation": "inversion", "pmut": 1/10, "pcross": 0.7, "elitism": True, "T": 10},
    {"crossover":"ox", "mutation": "inversion", "pmut": 1/10, "pcross": 0.8, "elitism": True, "T": 10},

    {"crossover":"ox", "mutation": "inversion", "pmut": 1/10, "pcross": 0.7, "elitism": True, "T": 12},
    {"crossover":"ox", "mutation": "inversion", "pmut": 1/10, "pcross": 0.8, "elitism": True, "T": 12},

    {"crossover":"pmx", "mutation": "inversion", "pmut": 1/10, "pcross": 0.7, "elitism": True, "T": 10},
    {"crossover":"pmx", "mutation": "inversion", "pmut": 1/10, "pcross": 0.8, "elitism": True, "T": 10},

    {"crossover":"pmx", "mutation": "inversion", "pmut": 1/10, "pcross": 0.7, "elitism": True, "T": 12},
    {"crossover":"pmx", "mutation": "inversion", "pmut": 1/10, "pcross": 0.8, "elitism": True, "T": 12},

    # scramble
    {"crossover":"ox", "mutation": "scramble", "pmut": 1/100, "pcross": 0.7, "elitism": True, "T": 10},
    {"crossover":"ox", "mutation": "scramble", "pmut": 1/100, "pcross": 0.8, "elitism": True, "T": 10},

    {"crossover":"ox", "mutation": "scramble", "pmut": 1/100, "pcross": 0.7, "elitism": True, "T": 12},
    {"crossover":"ox", "mutation": "scramble", "pmut": 1/100, "pcross": 0.8, "elitism": True, "T": 12},


    {"crossover":"pmx", "mutation": "scramble", "pmut": 1/100, "pcross": 0.7, "elitism": True, "T": 10},
    {"crossover":"pmx", "mutation": "scramble", "pmut": 1/100, "pcross": 0.8, "elitism": True, "T": 10},

    {"crossover":"pmx", "mutation": "scramble", "pmut": 1/100, "pcross": 0.7, "elitism": True, "T": 12},
    {"crossover":"pmx", "mutation": "scramble", "pmut": 1/100, "pcross": 0.8, "elitism": True, "T": 12},


    # --------------

    {"crossover":"ox", "mutation": "scramble", "pmut": 1/10, "pcross": 0.7, "elitism": True, "T": 10},
    {"crossover":"ox", "mutation": "scramble", "pmut": 1/10, "pcross": 0.8, "elitism": True, "T": 10},

    {"crossover":"ox", "mutation": "scramble", "pmut": 1/10, "pcross": 0.7, "elitism": True, "T": 12},
    {"crossover":"ox", "mutation": "scramble", "pmut": 1/10, "pcross": 0.8, "elitism": True, "T": 12},


    {"crossover":"pmx", "mutation": "scramble", "pmut": 1/10, "pcross": 0.7, "elitism": True, "T": 10},
    {"crossover":"pmx", "mutation": "scramble", "pmut": 1/10, "pcross": 0.8, "elitism": True, "T": 10},

    {"crossover":"pmx", "mutation": "scramble", "pmut": 1/10, "pcross": 0.7, "elitism": True, "T": 12},
    {"crossover":"pmx", "mutation": "scramble", "pmut": 1/10, "pcross": 0.8, "elitism": True, "T": 12},


    # random
    {"crossover":"ox", "mutation": "random", "pmut": 1/100, "pcross": 0.7, "elitism": True, "T": 10},
    {"crossover":"ox", "mutation": "random", "pmut": 1/100, "pcross": 0.8, "elitism": True, "T": 10},

    {"crossover":"ox", "mutation": "random", "pmut": 1/100, "pcross": 0.7, "elitism": True, "T": 12},
    {"crossover":"ox", "mutation": "random", "pmut": 1/100, "pcross": 0.8, "elitism": True, "T": 12},


    {"crossover":"pmx", "mutation": "random", "pmut": 1/100, "pcross": 0.7, "elitism": True, "T": 10},
    {"crossover":"pmx", "mutation": "random", "pmut": 1/100, "pcross": 0.8, "elitism": True, "T": 10},

    {"crossover":"pmx", "mutation": "random", "pmut": 1/100, "pcross": 0.7, "elitism": True, "T": 12},
    {"crossover":"pmx", "mutation": "random", "pmut": 1/100, "pcross": 0.8, "elitism": True, "T": 12},


    # --------------

    {"crossover":"ox", "mutation": "random", "pmut": 1/10, "pcross": 0.7, "elitism": True, "T": 10},
    {"crossover":"ox", "mutation": "random", "pmut": 1/10, "pcross": 0.8, "elitism": True, "T": 10},

    {"crossover":"ox", "mutation": "random", "pmut": 1/10, "pcross": 0.7, "elitism": True, "T": 12},
    {"crossover":"ox", "mutation": "random", "pmut": 1/10, "pcross": 0.8, "elitism": True, "T": 12},

    {"crossover":"pmx", "mutation": "random", "pmut": 1/10, "pcross": 0.7, "elitism": True, "T": 10},
    {"crossover":"pmx", "mutation": "random", "pmut": 1/10, "pcross": 0.8, "elitism": True, "T": 10},

    {"crossover":"pmx", "mutation": "random", "pmut": 1/10, "pcross": 0.7, "elitism": True, "T": 12},
    {"crossover":"pmx", "mutation": "random", "pmut": 1/10, "pcross": 0.8, "elitism": True, "T": 12},


]

# %%
import os

def run_experiment(cfg, run_id):
    random.seed(None)
    np.random.seed(None)

    pop = create(cities)

    pop, history = evolve(
        pop,
        globaldist,
        mutation=mutations[cfg["mutation"]],
        crossover=crossovers[cfg["crossover"]],
        pmut=cfg["pmut"],
        pcross=cfg["pcross"],
        T=cfg["T"],
        max_evals=1_000_000,
        elitism=cfg["elitism"]
    )

    best_val = globaldist(pop[0])

    folder = f"Logs/{run_id}"
    os.makedirs(folder, exist_ok=True)

    csv_path = (
        f"{folder}/CodGrupo_TSP_"
        f"{cfg['mutation']}_{cfg['pcross']}_{cfg['elitism']}_{cfg['pmut']}_{cfg['crossover']}_{cfg['T']}.csv"
    )

    with open(csv_path, "w", newline="") as f:
        writer = csv.writer(f)
        writer.writerow(["generation", "min_fitness"])
        writer.writerows(history)

    return best_val, csv_path

# %%
from joblib import Parallel, parallel_backend, delayed
import time

n_runs = 10
results = []

for cfg in configs:
    print("Running config:", cfg)

    start = time.perf_counter()

    with parallel_backend("loky", inner_max_num_threads=1):
        out = Parallel(n_jobs=32)(
            delayed(run_experiment)(cfg, i) for i in range(n_runs)
        )

    elapsed = time.perf_counter() - start

    vals = [r[0] for r in out]
    csv_files = [r[1] for r in out]

    results.append({
        "mutation": cfg["mutation"],
        "crossover": cfg["crossover"],
        "pcross": cfg["pcross"],
        "pmut": cfg["pmut"],
        "elitism": cfg["elitism"],
        "T": cfg["T"],
        "mean": np.mean(vals),
        "std": np.std(vals),
        "best": np.min(vals),
        "time_sec": elapsed,
        "files": csv_files
    })

    print(results[-1])
# Out:
# Running config: {'crossover': 'ox', 'mutation': 'swap', 'pmut': 0.01, 'pcross': 0.7, 'elitism': True, 'T': 10}
# {'mutation': 'swap', 'crossover': 'ox', 'pcross': 0.7, 'pmut': 0.01, 'elitism': True, 'T': 10, 'mean': np.float64(13.257458118090724), 'std': np.float64(0.5188348696538003), 'best': np.float64(12.352386225665795), 'time_sec': 503.551786955446, 'files': ['Logs/0/CodGrupo_TSP_swap_0.7_True_0.01_ox_10.csv', 'Logs/1/CodGrupo_TSP_swap_0.7_True_0.01_ox_10.csv', 'Logs/2/CodGrupo_TSP_swap_0.7_True_0.01_ox_10.csv', 'Logs/3/CodGrupo_TSP_swap_0.7_True_0.01_ox_10.csv', 'Logs/4/CodGrupo_TSP_swap_0.7_True_0.01_ox_10.csv', 'Logs/5/CodGrupo_TSP_swap_0.7_True_0.01_ox_10.csv', 'Logs/6/CodGrupo_TSP_swap_0.7_True_0.01_ox_10.csv', 'Logs/7/CodGrupo_TSP_swap_0.7_True_0.01_ox_10.csv', 'Logs/8/CodGrupo_TSP_swap_0.7_True_0.01_ox_10.csv', 'Logs/9/CodGrupo_TSP_swap_0.7_True_0.01_ox_10.csv']}
# Running config: {'crossover': 'ox', 'mutation': 'swap', 'pmut': 0.01, 'pcross': 0.8, 'elitism': True, 'T': 10}
# {'mutation': 'swap', 'crossover': 'ox', 'pcross': 0.8, 'pmut': 0.01, 'elitism': True, 'T': 10, 'mean': np.float64(13.76644286868021), 'std': np.float64(0.8970376917573967), 'best': np.float64(12.564226712650175), 'time_sec': 513.1918955724686, 'files': ['Logs/0/CodGrupo_TSP_swap_0.8_True_0.01_ox_10.csv', 'Logs/1/CodGrupo_TSP_swap_0.8_True_0.01_ox_10.csv', 'Logs/2/CodGrupo_TSP_swap_0.8_True_0.01_ox_10.csv', 'Logs/3/CodGrupo_TSP_swap_0.8_True_0.01_ox_10.csv', 'Logs/4/CodGrupo_TSP_swap_0.8_True_0.01_ox_10.csv', 'Logs/5/CodGrupo_TSP_swap_0.8_True_0.01_ox_10.csv', 'Logs/6/CodGrupo_TSP_swap_0.8_True_0.01_ox_10.csv', 'Logs/7/CodGrupo_TSP_swap_0.8_True_0.01_ox_10.csv', 'Logs/8/CodGrupo_TSP_swap_0.8_True_0.01_ox_10.csv', 'Logs/9/CodGrupo_TSP_swap_0.8_True_0.01_ox_10.csv']}
# Running config: {'crossover': 'ox', 'mutation': 'swap', 'pmut': 0.01, 'pcross': 0.7, 'elitism': True, 'T': 12}
# {'mutation': 'swap', 'crossover': 'ox', 'pcross': 0.7, 'pmut': 0.01, 'elitism': True, 'T': 12, 'mean': np.float64(14.084590634168602), 'std': np.float64(0.8618357839553409), 'best': np.float64(13.094858984896469), 'time_sec': 507.43700227700174, 'files': ['Logs/0/CodGrupo_TSP_swap_0.7_True_0.01_ox_12.csv', 'Logs/1/CodGrupo_TSP_swap_0.7_True_0.01_ox_12.csv', 'Logs/2/CodGrupo_TSP_swap_0.7_True_0.01_ox_12.csv', 'Logs/3/CodGrupo_TSP_swap_0.7_True_0.01_ox_12.csv', 'Logs/4/CodGrupo_TSP_swap_0.7_True_0.01_ox_12.csv', 'Logs/5/CodGrupo_TSP_swap_0.7_True_0.01_ox_12.csv', 'Logs/6/CodGrupo_TSP_swap_0.7_True_0.01_ox_12.csv', 'Logs/7/CodGrupo_TSP_swap_0.7_True_0.01_ox_12.csv', 'Logs/8/CodGrupo_TSP_swap_0.7_True_0.01_ox_12.csv', 'Logs/9/CodGrupo_TSP_swap_0.7_True_0.01_ox_12.csv']}
# Running config: {'crossover': 'ox', 'mutation': 'swap', 'pmut': 0.01, 'pcross': 0.8, 'elitism': True, 'T': 12}
# {'mutation': 'swap', 'crossover': 'ox', 'pcross': 0.8, 'pmut': 0.01, 'elitism': True, 'T': 12, 'mean': np.float64(13.704731093650977), 'std': np.float64(0.853905511991614), 'best': np.float64(12.487941674358963), 'time_sec': 511.8245631773025, 'files': ['Logs/0/CodGrupo_TSP_swap_0.8_True_0.01_ox_12.csv', 'Logs/1/CodGrupo_TSP_swap_0.8_True_0.01_ox_12.csv', 'Logs/2/CodGrupo_TSP_swap_0.8_True_0.01_ox_12.csv', 'Logs/3/CodGrupo_TSP_swap_0.8_True_0.01_ox_12.csv', 'Logs/4/CodGrupo_TSP_swap_0.8_True_0.01_ox_12.csv', 'Logs/5/CodGrupo_TSP_swap_0.8_True_0.01_ox_12.csv', 'Logs/6/CodGrupo_TSP_swap_0.8_True_0.01_ox_12.csv', 'Logs/7/CodGrupo_TSP_swap_0.8_True_0.01_ox_12.csv', 'Logs/8/CodGrupo_TSP_swap_0.8_True_0.01_ox_12.csv', 'Logs/9/CodGrupo_TSP_swap_0.8_True_0.01_ox_12.csv']}
# Running config: {'crossover': 'pmx', 'mutation': 'swap', 'pmut': 0.01, 'pcross': 0.7, 'elitism': True, 'T': 10}
# {'mutation': 'swap', 'crossover': 'pmx', 'pcross': 0.7, 'pmut': 0.01, 'elitism': True, 'T': 10, 'mean': np.float64(15.483928704703056), 'std': np.float64(1.4299237806809137), 'best': np.float64(12.976389109246462), 'time_sec': 383.40632267296314, 'files': ['Logs/0/CodGrupo_TSP_swap_0.7_True_0.01_pmx_10.csv', 'Logs/1/CodGrupo_TSP_swap_0.7_True_0.01_pmx_10.csv', 'Logs/2/CodGrupo_TSP_swap_0.7_True_0.01_pmx_10.csv', 'Logs/3/CodGrupo_TSP_swap_0.7_True_0.01_pmx_10.csv', 'Logs/4/CodGrupo_TSP_swap_0.7_True_0.01_pmx_10.csv', 'Logs/5/CodGrupo_TSP_swap_0.7_True_0.01_pmx_10.csv', 'Logs/6/CodGrupo_TSP_swap_0.7_True_0.01_pmx_10.csv', 'Logs/7/CodGrupo_TSP_swap_0.7_True_0.01_pmx_10.csv', 'Logs/8/CodGrupo_TSP_swap_0.7_True_0.01_pmx_10.csv', 'Logs/9/CodGrupo_TSP_swap_0.7_True_0.01_pmx_10.csv']}
# Running config: {'crossover': 'pmx', 'mutation': 'swap', 'pmut': 0.01, 'pcross': 0.8, 'elitism': True, 'T': 10}
# {'mutation': 'swap', 'crossover': 'pmx', 'pcross': 0.8, 'pmut': 0.01, 'elitism': True, 'T': 10, 'mean': np.float64(14.955648481608051), 'std': np.float64(0.7522145230361137), 'best': np.float64(13.718582168028888), 'time_sec': 375.2470999248326, 'files': ['Logs/0/CodGrupo_TSP_swap_0.8_True_0.01_pmx_10.csv', 'Logs/1/CodGrupo_TSP_swap_0.8_True_0.01_pmx_10.csv', 'Logs/2/CodGrupo_TSP_swap_0.8_True_0.01_pmx_10.csv', 'Logs/3/CodGrupo_TSP_swap_0.8_True_0.01_pmx_10.csv', 'Logs/4/CodGrupo_TSP_swap_0.8_True_0.01_pmx_10.csv', 'Logs/5/CodGrupo_TSP_swap_0.8_True_0.01_pmx_10.csv', 'Logs/6/CodGrupo_TSP_swap_0.8_True_0.01_pmx_10.csv', 'Logs/7/CodGrupo_TSP_swap_0.8_True_0.01_pmx_10.csv', 'Logs/8/CodGrupo_TSP_swap_0.8_True_0.01_pmx_10.csv', 'Logs/9/CodGrupo_TSP_swap_0.8_True_0.01_pmx_10.csv']}
# Running config: {'crossover': 'pmx', 'mutation': 'swap', 'pmut': 0.01, 'pcross': 0.7, 'elitism': True, 'T': 12}
# {'mutation': 'swap', 'crossover': 'pmx', 'pcross': 0.7, 'pmut': 0.01, 'elitism': True, 'T': 12, 'mean': np.float64(14.970210162435858), 'std': np.float64(0.8918719608292824), 'best': np.float64(13.53983206776603), 'time_sec': 386.56249991618097, 'files': ['Logs/0/CodGrupo_TSP_swap_0.7_True_0.01_pmx_12.csv', 'Logs/1/CodGrupo_TSP_swap_0.7_True_0.01_pmx_12.csv', 'Logs/2/CodGrupo_TSP_swap_0.7_True_0.01_pmx_12.csv', 'Logs/3/CodGrupo_TSP_swap_0.7_True_0.01_pmx_12.csv', 'Logs/4/CodGrupo_TSP_swap_0.7_True_0.01_pmx_12.csv', 'Logs/5/CodGrupo_TSP_swap_0.7_True_0.01_pmx_12.csv', 'Logs/6/CodGrupo_TSP_swap_0.7_True_0.01_pmx_12.csv', 'Logs/7/CodGrupo_TSP_swap_0.7_True_0.01_pmx_12.csv', 'Logs/8/CodGrupo_TSP_swap_0.7_True_0.01_pmx_12.csv', 'Logs/9/CodGrupo_TSP_swap_0.7_True_0.01_pmx_12.csv']}
# Running config: {'crossover': 'pmx', 'mutation': 'swap', 'pmut': 0.01, 'pcross': 0.8, 'elitism': True, 'T': 12}
# {'mutation': 'swap', 'crossover': 'pmx', 'pcross': 0.8, 'pmut': 0.01, 'elitism': True, 'T': 12, 'mean': np.float64(14.845575354479783), 'std': np.float64(1.0143956108738164), 'best': np.float64(13.579876010487451), 'time_sec': 377.6336299236864, 'files': ['Logs/0/CodGrupo_TSP_swap_0.8_True_0.01_pmx_12.csv', 'Logs/1/CodGrupo_TSP_swap_0.8_True_0.01_pmx_12.csv', 'Logs/2/CodGrupo_TSP_swap_0.8_True_0.01_pmx_12.csv', 'Logs/3/CodGrupo_TSP_swap_0.8_True_0.01_pmx_12.csv', 'Logs/4/CodGrupo_TSP_swap_0.8_True_0.01_pmx_12.csv', 'Logs/5/CodGrupo_TSP_swap_0.8_True_0.01_pmx_12.csv', 'Logs/6/CodGrupo_TSP_swap_0.8_True_0.01_pmx_12.csv', 'Logs/7/CodGrupo_TSP_swap_0.8_True_0.01_pmx_12.csv', 'Logs/8/CodGrupo_TSP_swap_0.8_True_0.01_pmx_12.csv', 'Logs/9/CodGrupo_TSP_swap_0.8_True_0.01_pmx_12.csv']}
# Running config: {'crossover': 'ox', 'mutation': 'swap', 'pmut': 0.1, 'pcross': 0.7, 'elitism': True, 'T': 10}
# {'mutation': 'swap', 'crossover': 'ox', 'pcross': 0.7, 'pmut': 0.1, 'elitism': True, 'T': 10, 'mean': np.float64(12.407477548205161), 'std': np.float64(0.6582842654399682), 'best': np.float64(11.498248020295634), 'time_sec': 506.4352327864617, 'files': ['Logs/0/CodGrupo_TSP_swap_0.7_True_0.1_ox_10.csv', 'Logs/1/CodGrupo_TSP_swap_0.7_True_0.1_ox_10.csv', 'Logs/2/CodGrupo_TSP_swap_0.7_True_0.1_ox_10.csv', 'Logs/3/CodGrupo_TSP_swap_0.7_True_0.1_ox_10.csv', 'Logs/4/CodGrupo_TSP_swap_0.7_True_0.1_ox_10.csv', 'Logs/5/CodGrupo_TSP_swap_0.7_True_0.1_ox_10.csv', 'Logs/6/CodGrupo_TSP_swap_0.7_True_0.1_ox_10.csv', 'Logs/7/CodGrupo_TSP_swap_0.7_True_0.1_ox_10.csv', 'Logs/8/CodGrupo_TSP_swap_0.7_True_0.1_ox_10.csv', 'Logs/9/CodGrupo_TSP_swap_0.7_True_0.1_ox_10.csv']}
# Running config: {'crossover': 'ox', 'mutation': 'swap', 'pmut': 0.1, 'pcross': 0.8, 'elitism': True, 'T': 10}
# {'mutation': 'swap', 'crossover': 'ox', 'pcross': 0.8, 'pmut': 0.1, 'elitism': True, 'T': 10, 'mean': np.float64(11.854281735574299), 'std': np.float64(0.3684823010999005), 'best': np.float64(11.404013676877991), 'time_sec': 513.6139010675251, 'files': ['Logs/0/CodGrupo_TSP_swap_0.8_True_0.1_ox_10.csv', 'Logs/1/CodGrupo_TSP_swap_0.8_True_0.1_ox_10.csv', 'Logs/2/CodGrupo_TSP_swap_0.8_True_0.1_ox_10.csv', 'Logs/3/CodGrupo_TSP_swap_0.8_True_0.1_ox_10.csv', 'Logs/4/CodGrupo_TSP_swap_0.8_True_0.1_ox_10.csv', 'Logs/5/CodGrupo_TSP_swap_0.8_True_0.1_ox_10.csv', 'Logs/6/CodGrupo_TSP_swap_0.8_True_0.1_ox_10.csv', 'Logs/7/CodGrupo_TSP_swap_0.8_True_0.1_ox_10.csv', 'Logs/8/CodGrupo_TSP_swap_0.8_True_0.1_ox_10.csv', 'Logs/9/CodGrupo_TSP_swap_0.8_True_0.1_ox_10.csv']}
# Running config: {'crossover': 'ox', 'mutation': 'swap', 'pmut': 0.1, 'pcross': 0.7, 'elitism': True, 'T': 12}
# {'mutation': 'swap', 'crossover': 'ox', 'pcross': 0.7, 'pmut': 0.1, 'elitism': True, 'T': 12, 'mean': np.float64(12.294223713198015), 'std': np.float64(0.6763936556009111), 'best': np.float64(11.290941747728032), 'time_sec': 504.92351556941867, 'files': ['Logs/0/CodGrupo_TSP_swap_0.7_True_0.1_ox_12.csv', 'Logs/1/CodGrupo_TSP_swap_0.7_True_0.1_ox_12.csv', 'Logs/2/CodGrupo_TSP_swap_0.7_True_0.1_ox_12.csv', 'Logs/3/CodGrupo_TSP_swap_0.7_True_0.1_ox_12.csv', 'Logs/4/CodGrupo_TSP_swap_0.7_True_0.1_ox_12.csv', 'Logs/5/CodGrupo_TSP_swap_0.7_True_0.1_ox_12.csv', 'Logs/6/CodGrupo_TSP_swap_0.7_True_0.1_ox_12.csv', 'Logs/7/CodGrupo_TSP_swap_0.7_True_0.1_ox_12.csv', 'Logs/8/CodGrupo_TSP_swap_0.7_True_0.1_ox_12.csv', 'Logs/9/CodGrupo_TSP_swap_0.7_True_0.1_ox_12.csv']}
# Running config: {'crossover': 'ox', 'mutation': 'swap', 'pmut': 0.1, 'pcross': 0.8, 'elitism': True, 'T': 12}
# {'mutation': 'swap', 'crossover': 'ox', 'pcross': 0.8, 'pmut': 0.1, 'elitism': True, 'T': 12, 'mean': np.float64(12.659369496169312), 'std': np.float64(0.9771189827573845), 'best': np.float64(10.73970608265565), 'time_sec': 513.3806657399982, 'files': ['Logs/0/CodGrupo_TSP_swap_0.8_True_0.1_ox_12.csv', 'Logs/1/CodGrupo_TSP_swap_0.8_True_0.1_ox_12.csv', 'Logs/2/CodGrupo_TSP_swap_0.8_True_0.1_ox_12.csv', 'Logs/3/CodGrupo_TSP_swap_0.8_True_0.1_ox_12.csv', 'Logs/4/CodGrupo_TSP_swap_0.8_True_0.1_ox_12.csv', 'Logs/5/CodGrupo_TSP_swap_0.8_True_0.1_ox_12.csv', 'Logs/6/CodGrupo_TSP_swap_0.8_True_0.1_ox_12.csv', 'Logs/7/CodGrupo_TSP_swap_0.8_True_0.1_ox_12.csv', 'Logs/8/CodGrupo_TSP_swap_0.8_True_0.1_ox_12.csv', 'Logs/9/CodGrupo_TSP_swap_0.8_True_0.1_ox_12.csv']}
# Running config: {'crossover': 'pmx', 'mutation': 'swap', 'pmut': 0.1, 'pcross': 0.7, 'elitism': True, 'T': 10}
# {'mutation': 'swap', 'crossover': 'pmx', 'pcross': 0.7, 'pmut': 0.1, 'elitism': True, 'T': 10, 'mean': np.float64(12.195884373642162), 'std': np.float64(0.5811023197101985), 'best': np.float64(11.344540412157386), 'time_sec': 384.3815458808094, 'files': ['Logs/0/CodGrupo_TSP_swap_0.7_True_0.1_pmx_10.csv', 'Logs/1/CodGrupo_TSP_swap_0.7_True_0.1_pmx_10.csv', 'Logs/2/CodGrupo_TSP_swap_0.7_True_0.1_pmx_10.csv', 'Logs/3/CodGrupo_TSP_swap_0.7_True_0.1_pmx_10.csv', 'Logs/4/CodGrupo_TSP_swap_0.7_True_0.1_pmx_10.csv', 'Logs/5/CodGrupo_TSP_swap_0.7_True_0.1_pmx_10.csv', 'Logs/6/CodGrupo_TSP_swap_0.7_True_0.1_pmx_10.csv', 'Logs/7/CodGrupo_TSP_swap_0.7_True_0.1_pmx_10.csv', 'Logs/8/CodGrupo_TSP_swap_0.7_True_0.1_pmx_10.csv', 'Logs/9/CodGrupo_TSP_swap_0.7_True_0.1_pmx_10.csv']}
# Running config: {'crossover': 'pmx', 'mutation': 'swap', 'pmut': 0.1, 'pcross': 0.8, 'elitism': True, 'T': 10}
# {'mutation': 'swap', 'crossover': 'pmx', 'pcross': 0.8, 'pmut': 0.1, 'elitism': True, 'T': 10, 'mean': np.float64(13.263985806168147), 'std': np.float64(0.788982157599518), 'best': np.float64(11.750965523032093), 'time_sec': 376.0232969429344, 'files': ['Logs/0/CodGrupo_TSP_swap_0.8_True_0.1_pmx_10.csv', 'Logs/1/CodGrupo_TSP_swap_0.8_True_0.1_pmx_10.csv', 'Logs/2/CodGrupo_TSP_swap_0.8_True_0.1_pmx_10.csv', 'Logs/3/CodGrupo_TSP_swap_0.8_True_0.1_pmx_10.csv', 'Logs/4/CodGrupo_TSP_swap_0.8_True_0.1_pmx_10.csv', 'Logs/5/CodGrupo_TSP_swap_0.8_True_0.1_pmx_10.csv', 'Logs/6/CodGrupo_TSP_swap_0.8_True_0.1_pmx_10.csv', 'Logs/7/CodGrupo_TSP_swap_0.8_True_0.1_pmx_10.csv', 'Logs/8/CodGrupo_TSP_swap_0.8_True_0.1_pmx_10.csv', 'Logs/9/CodGrupo_TSP_swap_0.8_True_0.1_pmx_10.csv']}
# Running config: {'crossover': 'pmx', 'mutation': 'swap', 'pmut': 0.1, 'pcross': 0.7, 'elitism': True, 'T': 12}
# {'mutation': 'swap', 'crossover': 'pmx', 'pcross': 0.7, 'pmut': 0.1, 'elitism': True, 'T': 12, 'mean': np.float64(12.767533969122521), 'std': np.float64(0.7558752617089908), 'best': np.float64(11.543447575100057), 'time_sec': 384.65043119341135, 'files': ['Logs/0/CodGrupo_TSP_swap_0.7_True_0.1_pmx_12.csv', 'Logs/1/CodGrupo_TSP_swap_0.7_True_0.1_pmx_12.csv', 'Logs/2/CodGrupo_TSP_swap_0.7_True_0.1_pmx_12.csv', 'Logs/3/CodGrupo_TSP_swap_0.7_True_0.1_pmx_12.csv', 'Logs/4/CodGrupo_TSP_swap_0.7_True_0.1_pmx_12.csv', 'Logs/5/CodGrupo_TSP_swap_0.7_True_0.1_pmx_12.csv', 'Logs/6/CodGrupo_TSP_swap_0.7_True_0.1_pmx_12.csv', 'Logs/7/CodGrupo_TSP_swap_0.7_True_0.1_pmx_12.csv', 'Logs/8/CodGrupo_TSP_swap_0.7_True_0.1_pmx_12.csv', 'Logs/9/CodGrupo_TSP_swap_0.7_True_0.1_pmx_12.csv']}
# Running config: {'crossover': 'pmx', 'mutation': 'swap', 'pmut': 0.1, 'pcross': 0.8, 'elitism': True, 'T': 12}
# {'mutation': 'swap', 'crossover': 'pmx', 'pcross': 0.8, 'pmut': 0.1, 'elitism': True, 'T': 12, 'mean': np.float64(12.964128780644984), 'std': np.float64(0.8462214720246418), 'best': np.float64(11.860817830999824), 'time_sec': 377.39354426786304, 'files': ['Logs/0/CodGrupo_TSP_swap_0.8_True_0.1_pmx_12.csv', 'Logs/1/CodGrupo_TSP_swap_0.8_True_0.1_pmx_12.csv', 'Logs/2/CodGrupo_TSP_swap_0.8_True_0.1_pmx_12.csv', 'Logs/3/CodGrupo_TSP_swap_0.8_True_0.1_pmx_12.csv', 'Logs/4/CodGrupo_TSP_swap_0.8_True_0.1_pmx_12.csv', 'Logs/5/CodGrupo_TSP_swap_0.8_True_0.1_pmx_12.csv', 'Logs/6/CodGrupo_TSP_swap_0.8_True_0.1_pmx_12.csv', 'Logs/7/CodGrupo_TSP_swap_0.8_True_0.1_pmx_12.csv', 'Logs/8/CodGrupo_TSP_swap_0.8_True_0.1_pmx_12.csv', 'Logs/9/CodGrupo_TSP_swap_0.8_True_0.1_pmx_12.csv']}
# Running config: {'crossover': 'ox', 'mutation': 'inversion', 'pmut': 0.01, 'pcross': 0.7, 'elitism': True, 'T': 10}
# {'mutation': 'inversion', 'crossover': 'ox', 'pcross': 0.7, 'pmut': 0.01, 'elitism': True, 'T': 10, 'mean': np.float64(8.86743294746859), 'std': np.float64(0.3151677247776098), 'best': np.float64(8.058231731154931), 'time_sec': 502.9818205833435, 'files': ['Logs/0/CodGrupo_TSP_inversion_0.7_True_0.01_ox_10.csv', 'Logs/1/CodGrupo_TSP_inversion_0.7_True_0.01_ox_10.csv', 'Logs/2/CodGrupo_TSP_inversion_0.7_True_0.01_ox_10.csv', 'Logs/3/CodGrupo_TSP_inversion_0.7_True_0.01_ox_10.csv', 'Logs/4/CodGrupo_TSP_inversion_0.7_True_0.01_ox_10.csv', 'Logs/5/CodGrupo_TSP_inversion_0.7_True_0.01_ox_10.csv', 'Logs/6/CodGrupo_TSP_inversion_0.7_True_0.01_ox_10.csv', 'Logs/7/CodGrupo_TSP_inversion_0.7_True_0.01_ox_10.csv', 'Logs/8/CodGrupo_TSP_inversion_0.7_True_0.01_ox_10.csv', 'Logs/9/CodGrupo_TSP_inversion_0.7_True_0.01_ox_10.csv']}
# Running config: {'crossover': 'ox', 'mutation': 'inversion', 'pmut': 0.01, 'pcross': 0.8, 'elitism': True, 'T': 10}
# {'mutation': 'inversion', 'crossover': 'ox', 'pcross': 0.8, 'pmut': 0.01, 'elitism': True, 'T': 10, 'mean': np.float64(8.850289415122592), 'std': np.float64(0.2690121721945333), 'best': np.float64(8.443652877307342), 'time_sec': 514.7646450847387, 'files': ['Logs/0/CodGrupo_TSP_inversion_0.8_True_0.01_ox_10.csv', 'Logs/1/CodGrupo_TSP_inversion_0.8_True_0.01_ox_10.csv', 'Logs/2/CodGrupo_TSP_inversion_0.8_True_0.01_ox_10.csv', 'Logs/3/CodGrupo_TSP_inversion_0.8_True_0.01_ox_10.csv', 'Logs/4/CodGrupo_TSP_inversion_0.8_True_0.01_ox_10.csv', 'Logs/5/CodGrupo_TSP_inversion_0.8_True_0.01_ox_10.csv', 'Logs/6/CodGrupo_TSP_inversion_0.8_True_0.01_ox_10.csv', 'Logs/7/CodGrupo_TSP_inversion_0.8_True_0.01_ox_10.csv', 'Logs/8/CodGrupo_TSP_inversion_0.8_True_0.01_ox_10.csv', 'Logs/9/CodGrupo_TSP_inversion_0.8_True_0.01_ox_10.csv']}
# Running config: {'crossover': 'ox', 'mutation': 'inversion', 'pmut': 0.01, 'pcross': 0.7, 'elitism': True, 'T': 12}
# {'mutation': 'inversion', 'crossover': 'ox', 'pcross': 0.7, 'pmut': 0.01, 'elitism': True, 'T': 12, 'mean': np.float64(8.93711500960621), 'std': np.float64(0.25362720892793456), 'best': np.float64(8.626194398895128), 'time_sec': 503.1468372605741, 'files': ['Logs/0/CodGrupo_TSP_inversion_0.7_True_0.01_ox_12.csv', 'Logs/1/CodGrupo_TSP_inversion_0.7_True_0.01_ox_12.csv', 'Logs/2/CodGrupo_TSP_inversion_0.7_True_0.01_ox_12.csv', 'Logs/3/CodGrupo_TSP_inversion_0.7_True_0.01_ox_12.csv', 'Logs/4/CodGrupo_TSP_inversion_0.7_True_0.01_ox_12.csv', 'Logs/5/CodGrupo_TSP_inversion_0.7_True_0.01_ox_12.csv', 'Logs/6/CodGrupo_TSP_inversion_0.7_True_0.01_ox_12.csv', 'Logs/7/CodGrupo_TSP_inversion_0.7_True_0.01_ox_12.csv', 'Logs/8/CodGrupo_TSP_inversion_0.7_True_0.01_ox_12.csv', 'Logs/9/CodGrupo_TSP_inversion_0.7_True_0.01_ox_12.csv']}
# Running config: {'crossover': 'ox', 'mutation': 'inversion', 'pmut': 0.01, 'pcross': 0.8, 'elitism': True, 'T': 12}
# {'mutation': 'inversion', 'crossover': 'ox', 'pcross': 0.8, 'pmut': 0.01, 'elitism': True, 'T': 12, 'mean': np.float64(8.807460269852204), 'std': np.float64(0.3592934171648439), 'best': np.float64(8.349341844140078), 'time_sec': 513.4584219716489, 'files': ['Logs/0/CodGrupo_TSP_inversion_0.8_True_0.01_ox_12.csv', 'Logs/1/CodGrupo_TSP_inversion_0.8_True_0.01_ox_12.csv', 'Logs/2/CodGrupo_TSP_inversion_0.8_True_0.01_ox_12.csv', 'Logs/3/CodGrupo_TSP_inversion_0.8_True_0.01_ox_12.csv', 'Logs/4/CodGrupo_TSP_inversion_0.8_True_0.01_ox_12.csv', 'Logs/5/CodGrupo_TSP_inversion_0.8_True_0.01_ox_12.csv', 'Logs/6/CodGrupo_TSP_inversion_0.8_True_0.01_ox_12.csv', 'Logs/7/CodGrupo_TSP_inversion_0.8_True_0.01_ox_12.csv', 'Logs/8/CodGrupo_TSP_inversion_0.8_True_0.01_ox_12.csv', 'Logs/9/CodGrupo_TSP_inversion_0.8_True_0.01_ox_12.csv']}
# Running config: {'crossover': 'pmx', 'mutation': 'inversion', 'pmut': 0.01, 'pcross': 0.7, 'elitism': True, 'T': 10}
# {'mutation': 'inversion', 'crossover': 'pmx', 'pcross': 0.7, 'pmut': 0.01, 'elitism': True, 'T': 10, 'mean': np.float64(9.046654085660979), 'std': np.float64(0.15501390981703667), 'best': np.float64(8.80952856596915), 'time_sec': 383.0228731315583, 'files': ['Logs/0/CodGrupo_TSP_inversion_0.7_True_0.01_pmx_10.csv', 'Logs/1/CodGrupo_TSP_inversion_0.7_True_0.01_pmx_10.csv', 'Logs/2/CodGrupo_TSP_inversion_0.7_True_0.01_pmx_10.csv', 'Logs/3/CodGrupo_TSP_inversion_0.7_True_0.01_pmx_10.csv', 'Logs/4/CodGrupo_TSP_inversion_0.7_True_0.01_pmx_10.csv', 'Logs/5/CodGrupo_TSP_inversion_0.7_True_0.01_pmx_10.csv', 'Logs/6/CodGrupo_TSP_inversion_0.7_True_0.01_pmx_10.csv', 'Logs/7/CodGrupo_TSP_inversion_0.7_True_0.01_pmx_10.csv', 'Logs/8/CodGrupo_TSP_inversion_0.7_True_0.01_pmx_10.csv', 'Logs/9/CodGrupo_TSP_inversion_0.7_True_0.01_pmx_10.csv']}
# Running config: {'crossover': 'pmx', 'mutation': 'inversion', 'pmut': 0.01, 'pcross': 0.8, 'elitism': True, 'T': 10}
# {'mutation': 'inversion', 'crossover': 'pmx', 'pcross': 0.8, 'pmut': 0.01, 'elitism': True, 'T': 10, 'mean': np.float64(9.17281754247039), 'std': np.float64(0.34281690457745567), 'best': np.float64(8.607706607622369), 'time_sec': 373.7763772755861, 'files': ['Logs/0/CodGrupo_TSP_inversion_0.8_True_0.01_pmx_10.csv', 'Logs/1/CodGrupo_TSP_inversion_0.8_True_0.01_pmx_10.csv', 'Logs/2/CodGrupo_TSP_inversion_0.8_True_0.01_pmx_10.csv', 'Logs/3/CodGrupo_TSP_inversion_0.8_True_0.01_pmx_10.csv', 'Logs/4/CodGrupo_TSP_inversion_0.8_True_0.01_pmx_10.csv', 'Logs/5/CodGrupo_TSP_inversion_0.8_True_0.01_pmx_10.csv', 'Logs/6/CodGrupo_TSP_inversion_0.8_True_0.01_pmx_10.csv', 'Logs/7/CodGrupo_TSP_inversion_0.8_True_0.01_pmx_10.csv', 'Logs/8/CodGrupo_TSP_inversion_0.8_True_0.01_pmx_10.csv', 'Logs/9/CodGrupo_TSP_inversion_0.8_True_0.01_pmx_10.csv']}
# Running config: {'crossover': 'pmx', 'mutation': 'inversion', 'pmut': 0.01, 'pcross': 0.7, 'elitism': True, 'T': 12}
# {'mutation': 'inversion', 'crossover': 'pmx', 'pcross': 0.7, 'pmut': 0.01, 'elitism': True, 'T': 12, 'mean': np.float64(9.166471911572623), 'std': np.float64(0.28802311415290166), 'best': np.float64(8.746415238339612), 'time_sec': 383.32305571064353, 'files': ['Logs/0/CodGrupo_TSP_inversion_0.7_True_0.01_pmx_12.csv', 'Logs/1/CodGrupo_TSP_inversion_0.7_True_0.01_pmx_12.csv', 'Logs/2/CodGrupo_TSP_inversion_0.7_True_0.01_pmx_12.csv', 'Logs/3/CodGrupo_TSP_inversion_0.7_True_0.01_pmx_12.csv', 'Logs/4/CodGrupo_TSP_inversion_0.7_True_0.01_pmx_12.csv', 'Logs/5/CodGrupo_TSP_inversion_0.7_True_0.01_pmx_12.csv', 'Logs/6/CodGrupo_TSP_inversion_0.7_True_0.01_pmx_12.csv', 'Logs/7/CodGrupo_TSP_inversion_0.7_True_0.01_pmx_12.csv', 'Logs/8/CodGrupo_TSP_inversion_0.7_True_0.01_pmx_12.csv', 'Logs/9/CodGrupo_TSP_inversion_0.7_True_0.01_pmx_12.csv']}
# Running config: {'crossover': 'pmx', 'mutation': 'inversion', 'pmut': 0.01, 'pcross': 0.8, 'elitism': True, 'T': 12}
# {'mutation': 'inversion', 'crossover': 'pmx', 'pcross': 0.8, 'pmut': 0.01, 'elitism': True, 'T': 12, 'mean': np.float64(9.170509657436686), 'std': np.float64(0.36069547393895757), 'best': np.float64(8.673044708664516), 'time_sec': 375.9805314466357, 'files': ['Logs/0/CodGrupo_TSP_inversion_0.8_True_0.01_pmx_12.csv', 'Logs/1/CodGrupo_TSP_inversion_0.8_True_0.01_pmx_12.csv', 'Logs/2/CodGrupo_TSP_inversion_0.8_True_0.01_pmx_12.csv', 'Logs/3/CodGrupo_TSP_inversion_0.8_True_0.01_pmx_12.csv', 'Logs/4/CodGrupo_TSP_inversion_0.8_True_0.01_pmx_12.csv', 'Logs/5/CodGrupo_TSP_inversion_0.8_True_0.01_pmx_12.csv', 'Logs/6/CodGrupo_TSP_inversion_0.8_True_0.01_pmx_12.csv', 'Logs/7/CodGrupo_TSP_inversion_0.8_True_0.01_pmx_12.csv', 'Logs/8/CodGrupo_TSP_inversion_0.8_True_0.01_pmx_12.csv', 'Logs/9/CodGrupo_TSP_inversion_0.8_True_0.01_pmx_12.csv']}
# Running config: {'crossover': 'ox', 'mutation': 'inversion', 'pmut': 0.1, 'pcross': 0.7, 'elitism': True, 'T': 10}
# {'mutation': 'inversion', 'crossover': 'ox', 'pcross': 0.7, 'pmut': 0.1, 'elitism': True, 'T': 10, 'mean': np.float64(8.250029626809319), 'std': np.float64(0.21524898346794918), 'best': np.float64(7.867251032826332), 'time_sec': 504.75663084350526, 'files': ['Logs/0/CodGrupo_TSP_inversion_0.7_True_0.1_ox_10.csv', 'Logs/1/CodGrupo_TSP_inversion_0.7_True_0.1_ox_10.csv', 'Logs/2/CodGrupo_TSP_inversion_0.7_True_0.1_ox_10.csv', 'Logs/3/CodGrupo_TSP_inversion_0.7_True_0.1_ox_10.csv', 'Logs/4/CodGrupo_TSP_inversion_0.7_True_0.1_ox_10.csv', 'Logs/5/CodGrupo_TSP_inversion_0.7_True_0.1_ox_10.csv', 'Logs/6/CodGrupo_TSP_inversion_0.7_True_0.1_ox_10.csv', 'Logs/7/CodGrupo_TSP_inversion_0.7_True_0.1_ox_10.csv', 'Logs/8/CodGrupo_TSP_inversion_0.7_True_0.1_ox_10.csv', 'Logs/9/CodGrupo_TSP_inversion_0.7_True_0.1_ox_10.csv']}
# Running config: {'crossover': 'ox', 'mutation': 'inversion', 'pmut': 0.1, 'pcross': 0.8, 'elitism': True, 'T': 10}
# {'mutation': 'inversion', 'crossover': 'ox', 'pcross': 0.8, 'pmut': 0.1, 'elitism': True, 'T': 10, 'mean': np.float64(8.39080699483716), 'std': np.float64(0.20979787360531363), 'best': np.float64(7.900818050870191), 'time_sec': 512.320044355467, 'files': ['Logs/0/CodGrupo_TSP_inversion_0.8_True_0.1_ox_10.csv', 'Logs/1/CodGrupo_TSP_inversion_0.8_True_0.1_ox_10.csv', 'Logs/2/CodGrupo_TSP_inversion_0.8_True_0.1_ox_10.csv', 'Logs/3/CodGrupo_TSP_inversion_0.8_True_0.1_ox_10.csv', 'Logs/4/CodGrupo_TSP_inversion_0.8_True_0.1_ox_10.csv', 'Logs/5/CodGrupo_TSP_inversion_0.8_True_0.1_ox_10.csv', 'Logs/6/CodGrupo_TSP_inversion_0.8_True_0.1_ox_10.csv', 'Logs/7/CodGrupo_TSP_inversion_0.8_True_0.1_ox_10.csv', 'Logs/8/CodGrupo_TSP_inversion_0.8_True_0.1_ox_10.csv', 'Logs/9/CodGrupo_TSP_inversion_0.8_True_0.1_ox_10.csv']}
# Running config: {'crossover': 'ox', 'mutation': 'inversion', 'pmut': 0.1, 'pcross': 0.7, 'elitism': True, 'T': 12}
# {'mutation': 'inversion', 'crossover': 'ox', 'pcross': 0.7, 'pmut': 0.1, 'elitism': True, 'T': 12, 'mean': np.float64(8.210132702786712), 'std': np.float64(0.1997401556594958), 'best': np.float64(7.940967829017174), 'time_sec': 504.1063252147287, 'files': ['Logs/0/CodGrupo_TSP_inversion_0.7_True_0.1_ox_12.csv', 'Logs/1/CodGrupo_TSP_inversion_0.7_True_0.1_ox_12.csv', 'Logs/2/CodGrupo_TSP_inversion_0.7_True_0.1_ox_12.csv', 'Logs/3/CodGrupo_TSP_inversion_0.7_True_0.1_ox_12.csv', 'Logs/4/CodGrupo_TSP_inversion_0.7_True_0.1_ox_12.csv', 'Logs/5/CodGrupo_TSP_inversion_0.7_True_0.1_ox_12.csv', 'Logs/6/CodGrupo_TSP_inversion_0.7_True_0.1_ox_12.csv', 'Logs/7/CodGrupo_TSP_inversion_0.7_True_0.1_ox_12.csv', 'Logs/8/CodGrupo_TSP_inversion_0.7_True_0.1_ox_12.csv', 'Logs/9/CodGrupo_TSP_inversion_0.7_True_0.1_ox_12.csv']}
# Running config: {'crossover': 'ox', 'mutation': 'inversion', 'pmut': 0.1, 'pcross': 0.8, 'elitism': True, 'T': 12}
# {'mutation': 'inversion', 'crossover': 'ox', 'pcross': 0.8, 'pmut': 0.1, 'elitism': True, 'T': 12, 'mean': np.float64(8.187349641239603), 'std': np.float64(0.19584750183387542), 'best': np.float64(7.828978563829255), 'time_sec': 514.1268867682666, 'files': ['Logs/0/CodGrupo_TSP_inversion_0.8_True_0.1_ox_12.csv', 'Logs/1/CodGrupo_TSP_inversion_0.8_True_0.1_ox_12.csv', 'Logs/2/CodGrupo_TSP_inversion_0.8_True_0.1_ox_12.csv', 'Logs/3/CodGrupo_TSP_inversion_0.8_True_0.1_ox_12.csv', 'Logs/4/CodGrupo_TSP_inversion_0.8_True_0.1_ox_12.csv', 'Logs/5/CodGrupo_TSP_inversion_0.8_True_0.1_ox_12.csv', 'Logs/6/CodGrupo_TSP_inversion_0.8_True_0.1_ox_12.csv', 'Logs/7/CodGrupo_TSP_inversion_0.8_True_0.1_ox_12.csv', 'Logs/8/CodGrupo_TSP_inversion_0.8_True_0.1_ox_12.csv', 'Logs/9/CodGrupo_TSP_inversion_0.8_True_0.1_ox_12.csv']}
# Running config: {'crossover': 'pmx', 'mutation': 'inversion', 'pmut': 0.1, 'pcross': 0.7, 'elitism': True, 'T': 10}
# {'mutation': 'inversion', 'crossover': 'pmx', 'pcross': 0.7, 'pmut': 0.1, 'elitism': True, 'T': 10, 'mean': np.float64(8.408484217530768), 'std': np.float64(0.17871398817843537), 'best': np.float64(8.015565399851402), 'time_sec': 382.90787135995924, 'files': ['Logs/0/CodGrupo_TSP_inversion_0.7_True_0.1_pmx_10.csv', 'Logs/1/CodGrupo_TSP_inversion_0.7_True_0.1_pmx_10.csv', 'Logs/2/CodGrupo_TSP_inversion_0.7_True_0.1_pmx_10.csv', 'Logs/3/CodGrupo_TSP_inversion_0.7_True_0.1_pmx_10.csv', 'Logs/4/CodGrupo_TSP_inversion_0.7_True_0.1_pmx_10.csv', 'Logs/5/CodGrupo_TSP_inversion_0.7_True_0.1_pmx_10.csv', 'Logs/6/CodGrupo_TSP_inversion_0.7_True_0.1_pmx_10.csv', 'Logs/7/CodGrupo_TSP_inversion_0.7_True_0.1_pmx_10.csv', 'Logs/8/CodGrupo_TSP_inversion_0.7_True_0.1_pmx_10.csv', 'Logs/9/CodGrupo_TSP_inversion_0.7_True_0.1_pmx_10.csv']}
# Running config: {'crossover': 'pmx', 'mutation': 'inversion', 'pmut': 0.1, 'pcross': 0.8, 'elitism': True, 'T': 10}
# {'mutation': 'inversion', 'crossover': 'pmx', 'pcross': 0.8, 'pmut': 0.1, 'elitism': True, 'T': 10, 'mean': np.float64(8.457270234364184), 'std': np.float64(0.23665537422471247), 'best': np.float64(8.032470926810175), 'time_sec': 376.41044200211763, 'files': ['Logs/0/CodGrupo_TSP_inversion_0.8_True_0.1_pmx_10.csv', 'Logs/1/CodGrupo_TSP_inversion_0.8_True_0.1_pmx_10.csv', 'Logs/2/CodGrupo_TSP_inversion_0.8_True_0.1_pmx_10.csv', 'Logs/3/CodGrupo_TSP_inversion_0.8_True_0.1_pmx_10.csv', 'Logs/4/CodGrupo_TSP_inversion_0.8_True_0.1_pmx_10.csv', 'Logs/5/CodGrupo_TSP_inversion_0.8_True_0.1_pmx_10.csv', 'Logs/6/CodGrupo_TSP_inversion_0.8_True_0.1_pmx_10.csv', 'Logs/7/CodGrupo_TSP_inversion_0.8_True_0.1_pmx_10.csv', 'Logs/8/CodGrupo_TSP_inversion_0.8_True_0.1_pmx_10.csv', 'Logs/9/CodGrupo_TSP_inversion_0.8_True_0.1_pmx_10.csv']}
# Running config: {'crossover': 'pmx', 'mutation': 'inversion', 'pmut': 0.1, 'pcross': 0.7, 'elitism': True, 'T': 12}
# {'mutation': 'inversion', 'crossover': 'pmx', 'pcross': 0.7, 'pmut': 0.1, 'elitism': True, 'T': 12, 'mean': np.float64(8.314035836816066), 'std': np.float64(0.17000282503276573), 'best': np.float64(7.963574795540763), 'time_sec': 384.0123074799776, 'files': ['Logs/0/CodGrupo_TSP_inversion_0.7_True_0.1_pmx_12.csv', 'Logs/1/CodGrupo_TSP_inversion_0.7_True_0.1_pmx_12.csv', 'Logs/2/CodGrupo_TSP_inversion_0.7_True_0.1_pmx_12.csv', 'Logs/3/CodGrupo_TSP_inversion_0.7_True_0.1_pmx_12.csv', 'Logs/4/CodGrupo_TSP_inversion_0.7_True_0.1_pmx_12.csv', 'Logs/5/CodGrupo_TSP_inversion_0.7_True_0.1_pmx_12.csv', 'Logs/6/CodGrupo_TSP_inversion_0.7_True_0.1_pmx_12.csv', 'Logs/7/CodGrupo_TSP_inversion_0.7_True_0.1_pmx_12.csv', 'Logs/8/CodGrupo_TSP_inversion_0.7_True_0.1_pmx_12.csv', 'Logs/9/CodGrupo_TSP_inversion_0.7_True_0.1_pmx_12.csv']}
# Running config: {'crossover': 'pmx', 'mutation': 'inversion', 'pmut': 0.1, 'pcross': 0.8, 'elitism': True, 'T': 12}
# {'mutation': 'inversion', 'crossover': 'pmx', 'pcross': 0.8, 'pmut': 0.1, 'elitism': True, 'T': 12, 'mean': np.float64(8.283694710950689), 'std': np.float64(0.18894863313044602), 'best': np.float64(7.859915263181751), 'time_sec': 378.17141642794013, 'files': ['Logs/0/CodGrupo_TSP_inversion_0.8_True_0.1_pmx_12.csv', 'Logs/1/CodGrupo_TSP_inversion_0.8_True_0.1_pmx_12.csv', 'Logs/2/CodGrupo_TSP_inversion_0.8_True_0.1_pmx_12.csv', 'Logs/3/CodGrupo_TSP_inversion_0.8_True_0.1_pmx_12.csv', 'Logs/4/CodGrupo_TSP_inversion_0.8_True_0.1_pmx_12.csv', 'Logs/5/CodGrupo_TSP_inversion_0.8_True_0.1_pmx_12.csv', 'Logs/6/CodGrupo_TSP_inversion_0.8_True_0.1_pmx_12.csv', 'Logs/7/CodGrupo_TSP_inversion_0.8_True_0.1_pmx_12.csv', 'Logs/8/CodGrupo_TSP_inversion_0.8_True_0.1_pmx_12.csv', 'Logs/9/CodGrupo_TSP_inversion_0.8_True_0.1_pmx_12.csv']}
# Running config: {'crossover': 'ox', 'mutation': 'scramble', 'pmut': 0.01, 'pcross': 0.7, 'elitism': True, 'T': 10}
# {'mutation': 'scramble', 'crossover': 'ox', 'pcross': 0.7, 'pmut': 0.01, 'elitism': True, 'T': 10, 'mean': np.float64(21.379092509638006), 'std': np.float64(0.939620024068095), 'best': np.float64(20.13585419291208), 'time_sec': 501.60851632244885, 'files': ['Logs/0/CodGrupo_TSP_scramble_0.7_True_0.01_ox_10.csv', 'Logs/1/CodGrupo_TSP_scramble_0.7_True_0.01_ox_10.csv', 'Logs/2/CodGrupo_TSP_scramble_0.7_True_0.01_ox_10.csv', 'Logs/3/CodGrupo_TSP_scramble_0.7_True_0.01_ox_10.csv', 'Logs/4/CodGrupo_TSP_scramble_0.7_True_0.01_ox_10.csv', 'Logs/5/CodGrupo_TSP_scramble_0.7_True_0.01_ox_10.csv', 'Logs/6/CodGrupo_TSP_scramble_0.7_True_0.01_ox_10.csv', 'Logs/7/CodGrupo_TSP_scramble_0.7_True_0.01_ox_10.csv', 'Logs/8/CodGrupo_TSP_scramble_0.7_True_0.01_ox_10.csv', 'Logs/9/CodGrupo_TSP_scramble_0.7_True_0.01_ox_10.csv']}
# Running config: {'crossover': 'ox', 'mutation': 'scramble', 'pmut': 0.01, 'pcross': 0.8, 'elitism': True, 'T': 10}
# {'mutation': 'scramble', 'crossover': 'ox', 'pcross': 0.8, 'pmut': 0.01, 'elitism': True, 'T': 10, 'mean': np.float64(19.613793675406225), 'std': np.float64(1.6968222901048078), 'best': np.float64(16.80338687241688), 'time_sec': 512.8162974156439, 'files': ['Logs/0/CodGrupo_TSP_scramble_0.8_True_0.01_ox_10.csv', 'Logs/1/CodGrupo_TSP_scramble_0.8_True_0.01_ox_10.csv', 'Logs/2/CodGrupo_TSP_scramble_0.8_True_0.01_ox_10.csv', 'Logs/3/CodGrupo_TSP_scramble_0.8_True_0.01_ox_10.csv', 'Logs/4/CodGrupo_TSP_scramble_0.8_True_0.01_ox_10.csv', 'Logs/5/CodGrupo_TSP_scramble_0.8_True_0.01_ox_10.csv', 'Logs/6/CodGrupo_TSP_scramble_0.8_True_0.01_ox_10.csv', 'Logs/7/CodGrupo_TSP_scramble_0.8_True_0.01_ox_10.csv', 'Logs/8/CodGrupo_TSP_scramble_0.8_True_0.01_ox_10.csv', 'Logs/9/CodGrupo_TSP_scramble_0.8_True_0.01_ox_10.csv']}
# Running config: {'crossover': 'ox', 'mutation': 'scramble', 'pmut': 0.01, 'pcross': 0.7, 'elitism': True, 'T': 12}
# {'mutation': 'scramble', 'crossover': 'ox', 'pcross': 0.7, 'pmut': 0.01, 'elitism': True, 'T': 12, 'mean': np.float64(22.27441154702796), 'std': np.float64(0.9147010712241199), 'best': np.float64(21.132106913616525), 'time_sec': 504.0038317590952, 'files': ['Logs/0/CodGrupo_TSP_scramble_0.7_True_0.01_ox_12.csv', 'Logs/1/CodGrupo_TSP_scramble_0.7_True_0.01_ox_12.csv', 'Logs/2/CodGrupo_TSP_scramble_0.7_True_0.01_ox_12.csv', 'Logs/3/CodGrupo_TSP_scramble_0.7_True_0.01_ox_12.csv', 'Logs/4/CodGrupo_TSP_scramble_0.7_True_0.01_ox_12.csv', 'Logs/5/CodGrupo_TSP_scramble_0.7_True_0.01_ox_12.csv', 'Logs/6/CodGrupo_TSP_scramble_0.7_True_0.01_ox_12.csv', 'Logs/7/CodGrupo_TSP_scramble_0.7_True_0.01_ox_12.csv', 'Logs/8/CodGrupo_TSP_scramble_0.7_True_0.01_ox_12.csv', 'Logs/9/CodGrupo_TSP_scramble_0.7_True_0.01_ox_12.csv']}
# Running config: {'crossover': 'ox', 'mutation': 'scramble', 'pmut': 0.01, 'pcross': 0.8, 'elitism': True, 'T': 12}
# {'mutation': 'scramble', 'crossover': 'ox', 'pcross': 0.8, 'pmut': 0.01, 'elitism': True, 'T': 12, 'mean': np.float64(19.629199285500036), 'std': np.float64(2.6178453951539193), 'best': np.float64(15.83502398630683), 'time_sec': 513.8970825653523, 'files': ['Logs/0/CodGrupo_TSP_scramble_0.8_True_0.01_ox_12.csv', 'Logs/1/CodGrupo_TSP_scramble_0.8_True_0.01_ox_12.csv', 'Logs/2/CodGrupo_TSP_scramble_0.8_True_0.01_ox_12.csv', 'Logs/3/CodGrupo_TSP_scramble_0.8_True_0.01_ox_12.csv', 'Logs/4/CodGrupo_TSP_scramble_0.8_True_0.01_ox_12.csv', 'Logs/5/CodGrupo_TSP_scramble_0.8_True_0.01_ox_12.csv', 'Logs/6/CodGrupo_TSP_scramble_0.8_True_0.01_ox_12.csv', 'Logs/7/CodGrupo_TSP_scramble_0.8_True_0.01_ox_12.csv', 'Logs/8/CodGrupo_TSP_scramble_0.8_True_0.01_ox_12.csv', 'Logs/9/CodGrupo_TSP_scramble_0.8_True_0.01_ox_12.csv']}
# Running config: {'crossover': 'pmx', 'mutation': 'scramble', 'pmut': 0.01, 'pcross': 0.7, 'elitism': True, 'T': 10}
# {'mutation': 'scramble', 'crossover': 'pmx', 'pcross': 0.7, 'pmut': 0.01, 'elitism': True, 'T': 10, 'mean': np.float64(24.339077419541784), 'std': np.float64(1.0157707503685225), 'best': np.float64(22.902939679916567), 'time_sec': 382.5525088123977, 'files': ['Logs/0/CodGrupo_TSP_scramble_0.7_True_0.01_pmx_10.csv', 'Logs/1/CodGrupo_TSP_scramble_0.7_True_0.01_pmx_10.csv', 'Logs/2/CodGrupo_TSP_scramble_0.7_True_0.01_pmx_10.csv', 'Logs/3/CodGrupo_TSP_scramble_0.7_True_0.01_pmx_10.csv', 'Logs/4/CodGrupo_TSP_scramble_0.7_True_0.01_pmx_10.csv', 'Logs/5/CodGrupo_TSP_scramble_0.7_True_0.01_pmx_10.csv', 'Logs/6/CodGrupo_TSP_scramble_0.7_True_0.01_pmx_10.csv', 'Logs/7/CodGrupo_TSP_scramble_0.7_True_0.01_pmx_10.csv', 'Logs/8/CodGrupo_TSP_scramble_0.7_True_0.01_pmx_10.csv', 'Logs/9/CodGrupo_TSP_scramble_0.7_True_0.01_pmx_10.csv']}
# Running config: {'crossover': 'pmx', 'mutation': 'scramble', 'pmut': 0.01, 'pcross': 0.8, 'elitism': True, 'T': 10}
# {'mutation': 'scramble', 'crossover': 'pmx', 'pcross': 0.8, 'pmut': 0.01, 'elitism': True, 'T': 10, 'mean': np.float64(24.44517061487969), 'std': np.float64(1.3833934521855893), 'best': np.float64(21.79758003577675), 'time_sec': 377.0660567320883, 'files': ['Logs/0/CodGrupo_TSP_scramble_0.8_True_0.01_pmx_10.csv', 'Logs/1/CodGrupo_TSP_scramble_0.8_True_0.01_pmx_10.csv', 'Logs/2/CodGrupo_TSP_scramble_0.8_True_0.01_pmx_10.csv', 'Logs/3/CodGrupo_TSP_scramble_0.8_True_0.01_pmx_10.csv', 'Logs/4/CodGrupo_TSP_scramble_0.8_True_0.01_pmx_10.csv', 'Logs/5/CodGrupo_TSP_scramble_0.8_True_0.01_pmx_10.csv', 'Logs/6/CodGrupo_TSP_scramble_0.8_True_0.01_pmx_10.csv', 'Logs/7/CodGrupo_TSP_scramble_0.8_True_0.01_pmx_10.csv', 'Logs/8/CodGrupo_TSP_scramble_0.8_True_0.01_pmx_10.csv', 'Logs/9/CodGrupo_TSP_scramble_0.8_True_0.01_pmx_10.csv']}
# Running config: {'crossover': 'pmx', 'mutation': 'scramble', 'pmut': 0.01, 'pcross': 0.7, 'elitism': True, 'T': 12}
# {'mutation': 'scramble', 'crossover': 'pmx', 'pcross': 0.7, 'pmut': 0.01, 'elitism': True, 'T': 12, 'mean': np.float64(25.05022988880312), 'std': np.float64(1.1331843989409898), 'best': np.float64(23.79273741611084), 'time_sec': 384.4875992797315, 'files': ['Logs/0/CodGrupo_TSP_scramble_0.7_True_0.01_pmx_12.csv', 'Logs/1/CodGrupo_TSP_scramble_0.7_True_0.01_pmx_12.csv', 'Logs/2/CodGrupo_TSP_scramble_0.7_True_0.01_pmx_12.csv', 'Logs/3/CodGrupo_TSP_scramble_0.7_True_0.01_pmx_12.csv', 'Logs/4/CodGrupo_TSP_scramble_0.7_True_0.01_pmx_12.csv', 'Logs/5/CodGrupo_TSP_scramble_0.7_True_0.01_pmx_12.csv', 'Logs/6/CodGrupo_TSP_scramble_0.7_True_0.01_pmx_12.csv', 'Logs/7/CodGrupo_TSP_scramble_0.7_True_0.01_pmx_12.csv', 'Logs/8/CodGrupo_TSP_scramble_0.7_True_0.01_pmx_12.csv', 'Logs/9/CodGrupo_TSP_scramble_0.7_True_0.01_pmx_12.csv']}
# Running config: {'crossover': 'pmx', 'mutation': 'scramble', 'pmut': 0.01, 'pcross': 0.8, 'elitism': True, 'T': 12}
# {'mutation': 'scramble', 'crossover': 'pmx', 'pcross': 0.8, 'pmut': 0.01, 'elitism': True, 'T': 12, 'mean': np.float64(25.826618372061045), 'std': np.float64(0.9771070408860799), 'best': np.float64(24.47929708959298), 'time_sec': 376.78708216920495, 'files': ['Logs/0/CodGrupo_TSP_scramble_0.8_True_0.01_pmx_12.csv', 'Logs/1/CodGrupo_TSP_scramble_0.8_True_0.01_pmx_12.csv', 'Logs/2/CodGrupo_TSP_scramble_0.8_True_0.01_pmx_12.csv', 'Logs/3/CodGrupo_TSP_scramble_0.8_True_0.01_pmx_12.csv', 'Logs/4/CodGrupo_TSP_scramble_0.8_True_0.01_pmx_12.csv', 'Logs/5/CodGrupo_TSP_scramble_0.8_True_0.01_pmx_12.csv', 'Logs/6/CodGrupo_TSP_scramble_0.8_True_0.01_pmx_12.csv', 'Logs/7/CodGrupo_TSP_scramble_0.8_True_0.01_pmx_12.csv', 'Logs/8/CodGrupo_TSP_scramble_0.8_True_0.01_pmx_12.csv', 'Logs/9/CodGrupo_TSP_scramble_0.8_True_0.01_pmx_12.csv']}
# Running config: {'crossover': 'ox', 'mutation': 'scramble', 'pmut': 0.1, 'pcross': 0.7, 'elitism': True, 'T': 10}
# {'mutation': 'scramble', 'crossover': 'ox', 'pcross': 0.7, 'pmut': 0.1, 'elitism': True, 'T': 10, 'mean': np.float64(18.78854010660108), 'std': np.float64(1.5522828999340241), 'best': np.float64(16.033995541619525), 'time_sec': 503.6858196835965, 'files': ['Logs/0/CodGrupo_TSP_scramble_0.7_True_0.1_ox_10.csv', 'Logs/1/CodGrupo_TSP_scramble_0.7_True_0.1_ox_10.csv', 'Logs/2/CodGrupo_TSP_scramble_0.7_True_0.1_ox_10.csv', 'Logs/3/CodGrupo_TSP_scramble_0.7_True_0.1_ox_10.csv', 'Logs/4/CodGrupo_TSP_scramble_0.7_True_0.1_ox_10.csv', 'Logs/5/CodGrupo_TSP_scramble_0.7_True_0.1_ox_10.csv', 'Logs/6/CodGrupo_TSP_scramble_0.7_True_0.1_ox_10.csv', 'Logs/7/CodGrupo_TSP_scramble_0.7_True_0.1_ox_10.csv', 'Logs/8/CodGrupo_TSP_scramble_0.7_True_0.1_ox_10.csv', 'Logs/9/CodGrupo_TSP_scramble_0.7_True_0.1_ox_10.csv']}
# Running config: {'crossover': 'ox', 'mutation': 'scramble', 'pmut': 0.1, 'pcross': 0.8, 'elitism': True, 'T': 10}
# {'mutation': 'scramble', 'crossover': 'ox', 'pcross': 0.8, 'pmut': 0.1, 'elitism': True, 'T': 10, 'mean': np.float64(17.74694627368229), 'std': np.float64(1.5783391569976484), 'best': np.float64(14.880665117807641), 'time_sec': 517.298697642982, 'files': ['Logs/0/CodGrupo_TSP_scramble_0.8_True_0.1_ox_10.csv', 'Logs/1/CodGrupo_TSP_scramble_0.8_True_0.1_ox_10.csv', 'Logs/2/CodGrupo_TSP_scramble_0.8_True_0.1_ox_10.csv', 'Logs/3/CodGrupo_TSP_scramble_0.8_True_0.1_ox_10.csv', 'Logs/4/CodGrupo_TSP_scramble_0.8_True_0.1_ox_10.csv', 'Logs/5/CodGrupo_TSP_scramble_0.8_True_0.1_ox_10.csv', 'Logs/6/CodGrupo_TSP_scramble_0.8_True_0.1_ox_10.csv', 'Logs/7/CodGrupo_TSP_scramble_0.8_True_0.1_ox_10.csv', 'Logs/8/CodGrupo_TSP_scramble_0.8_True_0.1_ox_10.csv', 'Logs/9/CodGrupo_TSP_scramble_0.8_True_0.1_ox_10.csv']}
# Running config: {'crossover': 'ox', 'mutation': 'scramble', 'pmut': 0.1, 'pcross': 0.7, 'elitism': True, 'T': 12}
# {'mutation': 'scramble', 'crossover': 'ox', 'pcross': 0.7, 'pmut': 0.1, 'elitism': True, 'T': 12, 'mean': np.float64(18.814337700960436), 'std': np.float64(1.1155649039042008), 'best': np.float64(16.200635285170232), 'time_sec': 506.0005469042808, 'files': ['Logs/0/CodGrupo_TSP_scramble_0.7_True_0.1_ox_12.csv', 'Logs/1/CodGrupo_TSP_scramble_0.7_True_0.1_ox_12.csv', 'Logs/2/CodGrupo_TSP_scramble_0.7_True_0.1_ox_12.csv', 'Logs/3/CodGrupo_TSP_scramble_0.7_True_0.1_ox_12.csv', 'Logs/4/CodGrupo_TSP_scramble_0.7_True_0.1_ox_12.csv', 'Logs/5/CodGrupo_TSP_scramble_0.7_True_0.1_ox_12.csv', 'Logs/6/CodGrupo_TSP_scramble_0.7_True_0.1_ox_12.csv', 'Logs/7/CodGrupo_TSP_scramble_0.7_True_0.1_ox_12.csv', 'Logs/8/CodGrupo_TSP_scramble_0.7_True_0.1_ox_12.csv', 'Logs/9/CodGrupo_TSP_scramble_0.7_True_0.1_ox_12.csv']}
# Running config: {'crossover': 'ox', 'mutation': 'scramble', 'pmut': 0.1, 'pcross': 0.8, 'elitism': True, 'T': 12}
# {'mutation': 'scramble', 'crossover': 'ox', 'pcross': 0.8, 'pmut': 0.1, 'elitism': True, 'T': 12, 'mean': np.float64(17.530375016323184), 'std': np.float64(1.2693209162843342), 'best': np.float64(15.447122201387513), 'time_sec': 517.1990081463009, 'files': ['Logs/0/CodGrupo_TSP_scramble_0.8_True_0.1_ox_12.csv', 'Logs/1/CodGrupo_TSP_scramble_0.8_True_0.1_ox_12.csv', 'Logs/2/CodGrupo_TSP_scramble_0.8_True_0.1_ox_12.csv', 'Logs/3/CodGrupo_TSP_scramble_0.8_True_0.1_ox_12.csv', 'Logs/4/CodGrupo_TSP_scramble_0.8_True_0.1_ox_12.csv', 'Logs/5/CodGrupo_TSP_scramble_0.8_True_0.1_ox_12.csv', 'Logs/6/CodGrupo_TSP_scramble_0.8_True_0.1_ox_12.csv', 'Logs/7/CodGrupo_TSP_scramble_0.8_True_0.1_ox_12.csv', 'Logs/8/CodGrupo_TSP_scramble_0.8_True_0.1_ox_12.csv', 'Logs/9/CodGrupo_TSP_scramble_0.8_True_0.1_ox_12.csv']}
# Running config: {'crossover': 'pmx', 'mutation': 'scramble', 'pmut': 0.1, 'pcross': 0.7, 'elitism': True, 'T': 10}
# {'mutation': 'scramble', 'crossover': 'pmx', 'pcross': 0.7, 'pmut': 0.1, 'elitism': True, 'T': 10, 'mean': np.float64(21.61563655078545), 'std': np.float64(1.1196993140985798), 'best': np.float64(19.49865698694098), 'time_sec': 384.41604653559625, 'files': ['Logs/0/CodGrupo_TSP_scramble_0.7_True_0.1_pmx_10.csv', 'Logs/1/CodGrupo_TSP_scramble_0.7_True_0.1_pmx_10.csv', 'Logs/2/CodGrupo_TSP_scramble_0.7_True_0.1_pmx_10.csv', 'Logs/3/CodGrupo_TSP_scramble_0.7_True_0.1_pmx_10.csv', 'Logs/4/CodGrupo_TSP_scramble_0.7_True_0.1_pmx_10.csv', 'Logs/5/CodGrupo_TSP_scramble_0.7_True_0.1_pmx_10.csv', 'Logs/6/CodGrupo_TSP_scramble_0.7_True_0.1_pmx_10.csv', 'Logs/7/CodGrupo_TSP_scramble_0.7_True_0.1_pmx_10.csv', 'Logs/8/CodGrupo_TSP_scramble_0.7_True_0.1_pmx_10.csv', 'Logs/9/CodGrupo_TSP_scramble_0.7_True_0.1_pmx_10.csv']}
# Running config: {'crossover': 'pmx', 'mutation': 'scramble', 'pmut': 0.1, 'pcross': 0.8, 'elitism': True, 'T': 10}
# {'mutation': 'scramble', 'crossover': 'pmx', 'pcross': 0.8, 'pmut': 0.1, 'elitism': True, 'T': 10, 'mean': np.float64(21.597126290053772), 'std': np.float64(1.1885395958998421), 'best': np.float64(19.485181197940776), 'time_sec': 377.2241334617138, 'files': ['Logs/0/CodGrupo_TSP_scramble_0.8_True_0.1_pmx_10.csv', 'Logs/1/CodGrupo_TSP_scramble_0.8_True_0.1_pmx_10.csv', 'Logs/2/CodGrupo_TSP_scramble_0.8_True_0.1_pmx_10.csv', 'Logs/3/CodGrupo_TSP_scramble_0.8_True_0.1_pmx_10.csv', 'Logs/4/CodGrupo_TSP_scramble_0.8_True_0.1_pmx_10.csv', 'Logs/5/CodGrupo_TSP_scramble_0.8_True_0.1_pmx_10.csv', 'Logs/6/CodGrupo_TSP_scramble_0.8_True_0.1_pmx_10.csv', 'Logs/7/CodGrupo_TSP_scramble_0.8_True_0.1_pmx_10.csv', 'Logs/8/CodGrupo_TSP_scramble_0.8_True_0.1_pmx_10.csv', 'Logs/9/CodGrupo_TSP_scramble_0.8_True_0.1_pmx_10.csv']}
# Running config: {'crossover': 'pmx', 'mutation': 'scramble', 'pmut': 0.1, 'pcross': 0.7, 'elitism': True, 'T': 12}
# {'mutation': 'scramble', 'crossover': 'pmx', 'pcross': 0.7, 'pmut': 0.1, 'elitism': True, 'T': 12, 'mean': np.float64(21.452891946794864), 'std': np.float64(0.8896229128007073), 'best': np.float64(20.446351529203294), 'time_sec': 387.0313592199236, 'files': ['Logs/0/CodGrupo_TSP_scramble_0.7_True_0.1_pmx_12.csv', 'Logs/1/CodGrupo_TSP_scramble_0.7_True_0.1_pmx_12.csv', 'Logs/2/CodGrupo_TSP_scramble_0.7_True_0.1_pmx_12.csv', 'Logs/3/CodGrupo_TSP_scramble_0.7_True_0.1_pmx_12.csv', 'Logs/4/CodGrupo_TSP_scramble_0.7_True_0.1_pmx_12.csv', 'Logs/5/CodGrupo_TSP_scramble_0.7_True_0.1_pmx_12.csv', 'Logs/6/CodGrupo_TSP_scramble_0.7_True_0.1_pmx_12.csv', 'Logs/7/CodGrupo_TSP_scramble_0.7_True_0.1_pmx_12.csv', 'Logs/8/CodGrupo_TSP_scramble_0.7_True_0.1_pmx_12.csv', 'Logs/9/CodGrupo_TSP_scramble_0.7_True_0.1_pmx_12.csv']}
# Running config: {'crossover': 'pmx', 'mutation': 'scramble', 'pmut': 0.1, 'pcross': 0.8, 'elitism': True, 'T': 12}
# {'mutation': 'scramble', 'crossover': 'pmx', 'pcross': 0.8, 'pmut': 0.1, 'elitism': True, 'T': 12, 'mean': np.float64(21.809944870455364), 'std': np.float64(0.7193617297474887), 'best': np.float64(20.615615758819878), 'time_sec': 379.5565513726324, 'files': ['Logs/0/CodGrupo_TSP_scramble_0.8_True_0.1_pmx_12.csv', 'Logs/1/CodGrupo_TSP_scramble_0.8_True_0.1_pmx_12.csv', 'Logs/2/CodGrupo_TSP_scramble_0.8_True_0.1_pmx_12.csv', 'Logs/3/CodGrupo_TSP_scramble_0.8_True_0.1_pmx_12.csv', 'Logs/4/CodGrupo_TSP_scramble_0.8_True_0.1_pmx_12.csv', 'Logs/5/CodGrupo_TSP_scramble_0.8_True_0.1_pmx_12.csv', 'Logs/6/CodGrupo_TSP_scramble_0.8_True_0.1_pmx_12.csv', 'Logs/7/CodGrupo_TSP_scramble_0.8_True_0.1_pmx_12.csv', 'Logs/8/CodGrupo_TSP_scramble_0.8_True_0.1_pmx_12.csv', 'Logs/9/CodGrupo_TSP_scramble_0.8_True_0.1_pmx_12.csv']}
# Running config: {'crossover': 'ox', 'mutation': 'random', 'pmut': 0.01, 'pcross': 0.7, 'elitism': True, 'T': 10}
# {'mutation': 'random', 'crossover': 'ox', 'pcross': 0.7, 'pmut': 0.01, 'elitism': True, 'T': 10, 'mean': np.float64(9.756971327309667), 'std': np.float64(0.4147625269968162), 'best': np.float64(8.830915469017903), 'time_sec': 503.766239175573, 'files': ['Logs/0/CodGrupo_TSP_random_0.7_True_0.01_ox_10.csv', 'Logs/1/CodGrupo_TSP_random_0.7_True_0.01_ox_10.csv', 'Logs/2/CodGrupo_TSP_random_0.7_True_0.01_ox_10.csv', 'Logs/3/CodGrupo_TSP_random_0.7_True_0.01_ox_10.csv', 'Logs/4/CodGrupo_TSP_random_0.7_True_0.01_ox_10.csv', 'Logs/5/CodGrupo_TSP_random_0.7_True_0.01_ox_10.csv', 'Logs/6/CodGrupo_TSP_random_0.7_True_0.01_ox_10.csv', 'Logs/7/CodGrupo_TSP_random_0.7_True_0.01_ox_10.csv', 'Logs/8/CodGrupo_TSP_random_0.7_True_0.01_ox_10.csv', 'Logs/9/CodGrupo_TSP_random_0.7_True_0.01_ox_10.csv']}
# Running config: {'crossover': 'ox', 'mutation': 'random', 'pmut': 0.01, 'pcross': 0.8, 'elitism': True, 'T': 10}
# {'mutation': 'random', 'crossover': 'ox', 'pcross': 0.8, 'pmut': 0.01, 'elitism': True, 'T': 10, 'mean': np.float64(9.866567320088318), 'std': np.float64(0.307877380544125), 'best': np.float64(9.256926504765902), 'time_sec': 513.4857441838831, 'files': ['Logs/0/CodGrupo_TSP_random_0.8_True_0.01_ox_10.csv', 'Logs/1/CodGrupo_TSP_random_0.8_True_0.01_ox_10.csv', 'Logs/2/CodGrupo_TSP_random_0.8_True_0.01_ox_10.csv', 'Logs/3/CodGrupo_TSP_random_0.8_True_0.01_ox_10.csv', 'Logs/4/CodGrupo_TSP_random_0.8_True_0.01_ox_10.csv', 'Logs/5/CodGrupo_TSP_random_0.8_True_0.01_ox_10.csv', 'Logs/6/CodGrupo_TSP_random_0.8_True_0.01_ox_10.csv', 'Logs/7/CodGrupo_TSP_random_0.8_True_0.01_ox_10.csv', 'Logs/8/CodGrupo_TSP_random_0.8_True_0.01_ox_10.csv', 'Logs/9/CodGrupo_TSP_random_0.8_True_0.01_ox_10.csv']}
# Running config: {'crossover': 'ox', 'mutation': 'random', 'pmut': 0.01, 'pcross': 0.7, 'elitism': True, 'T': 12}
# {'mutation': 'random', 'crossover': 'ox', 'pcross': 0.7, 'pmut': 0.01, 'elitism': True, 'T': 12, 'mean': np.float64(9.94933584535581), 'std': np.float64(0.272319664626129), 'best': np.float64(9.39747705454445), 'time_sec': 502.07228994742036, 'files': ['Logs/0/CodGrupo_TSP_random_0.7_True_0.01_ox_12.csv', 'Logs/1/CodGrupo_TSP_random_0.7_True_0.01_ox_12.csv', 'Logs/2/CodGrupo_TSP_random_0.7_True_0.01_ox_12.csv', 'Logs/3/CodGrupo_TSP_random_0.7_True_0.01_ox_12.csv', 'Logs/4/CodGrupo_TSP_random_0.7_True_0.01_ox_12.csv', 'Logs/5/CodGrupo_TSP_random_0.7_True_0.01_ox_12.csv', 'Logs/6/CodGrupo_TSP_random_0.7_True_0.01_ox_12.csv', 'Logs/7/CodGrupo_TSP_random_0.7_True_0.01_ox_12.csv', 'Logs/8/CodGrupo_TSP_random_0.7_True_0.01_ox_12.csv', 'Logs/9/CodGrupo_TSP_random_0.7_True_0.01_ox_12.csv']}
# Running config: {'crossover': 'ox', 'mutation': 'random', 'pmut': 0.01, 'pcross': 0.8, 'elitism': True, 'T': 12}
# {'mutation': 'random', 'crossover': 'ox', 'pcross': 0.8, 'pmut': 0.01, 'elitism': True, 'T': 12, 'mean': np.float64(9.62952102765164), 'std': np.float64(0.27381350148073014), 'best': np.float64(9.089978220713252), 'time_sec': 515.1589414253831, 'files': ['Logs/0/CodGrupo_TSP_random_0.8_True_0.01_ox_12.csv', 'Logs/1/CodGrupo_TSP_random_0.8_True_0.01_ox_12.csv', 'Logs/2/CodGrupo_TSP_random_0.8_True_0.01_ox_12.csv', 'Logs/3/CodGrupo_TSP_random_0.8_True_0.01_ox_12.csv', 'Logs/4/CodGrupo_TSP_random_0.8_True_0.01_ox_12.csv', 'Logs/5/CodGrupo_TSP_random_0.8_True_0.01_ox_12.csv', 'Logs/6/CodGrupo_TSP_random_0.8_True_0.01_ox_12.csv', 'Logs/7/CodGrupo_TSP_random_0.8_True_0.01_ox_12.csv', 'Logs/8/CodGrupo_TSP_random_0.8_True_0.01_ox_12.csv', 'Logs/9/CodGrupo_TSP_random_0.8_True_0.01_ox_12.csv']}
# Running config: {'crossover': 'pmx', 'mutation': 'random', 'pmut': 0.01, 'pcross': 0.7, 'elitism': True, 'T': 10}
# {'mutation': 'random', 'crossover': 'pmx', 'pcross': 0.7, 'pmut': 0.01, 'elitism': True, 'T': 10, 'mean': np.float64(10.141543165668622), 'std': np.float64(0.39656050896712725), 'best': np.float64(9.678679964813387), 'time_sec': 385.17325663752854, 'files': ['Logs/0/CodGrupo_TSP_random_0.7_True_0.01_pmx_10.csv', 'Logs/1/CodGrupo_TSP_random_0.7_True_0.01_pmx_10.csv', 'Logs/2/CodGrupo_TSP_random_0.7_True_0.01_pmx_10.csv', 'Logs/3/CodGrupo_TSP_random_0.7_True_0.01_pmx_10.csv', 'Logs/4/CodGrupo_TSP_random_0.7_True_0.01_pmx_10.csv', 'Logs/5/CodGrupo_TSP_random_0.7_True_0.01_pmx_10.csv', 'Logs/6/CodGrupo_TSP_random_0.7_True_0.01_pmx_10.csv', 'Logs/7/CodGrupo_TSP_random_0.7_True_0.01_pmx_10.csv', 'Logs/8/CodGrupo_TSP_random_0.7_True_0.01_pmx_10.csv', 'Logs/9/CodGrupo_TSP_random_0.7_True_0.01_pmx_10.csv']}
# Running config: {'crossover': 'pmx', 'mutation': 'random', 'pmut': 0.01, 'pcross': 0.8, 'elitism': True, 'T': 10}
# {'mutation': 'random', 'crossover': 'pmx', 'pcross': 0.8, 'pmut': 0.01, 'elitism': True, 'T': 10, 'mean': np.float64(10.347317057629235), 'std': np.float64(0.4260381314035992), 'best': np.float64(9.479993851886075), 'time_sec': 375.7421984728426, 'files': ['Logs/0/CodGrupo_TSP_random_0.8_True_0.01_pmx_10.csv', 'Logs/1/CodGrupo_TSP_random_0.8_True_0.01_pmx_10.csv', 'Logs/2/CodGrupo_TSP_random_0.8_True_0.01_pmx_10.csv', 'Logs/3/CodGrupo_TSP_random_0.8_True_0.01_pmx_10.csv', 'Logs/4/CodGrupo_TSP_random_0.8_True_0.01_pmx_10.csv', 'Logs/5/CodGrupo_TSP_random_0.8_True_0.01_pmx_10.csv', 'Logs/6/CodGrupo_TSP_random_0.8_True_0.01_pmx_10.csv', 'Logs/7/CodGrupo_TSP_random_0.8_True_0.01_pmx_10.csv', 'Logs/8/CodGrupo_TSP_random_0.8_True_0.01_pmx_10.csv', 'Logs/9/CodGrupo_TSP_random_0.8_True_0.01_pmx_10.csv']}
# Running config: {'crossover': 'pmx', 'mutation': 'random', 'pmut': 0.01, 'pcross': 0.7, 'elitism': True, 'T': 12}
# {'mutation': 'random', 'crossover': 'pmx', 'pcross': 0.7, 'pmut': 0.01, 'elitism': True, 'T': 12, 'mean': np.float64(10.442838865930224), 'std': np.float64(0.23674559881728388), 'best': np.float64(9.900816991177415), 'time_sec': 383.56355569697917, 'files': ['Logs/0/CodGrupo_TSP_random_0.7_True_0.01_pmx_12.csv', 'Logs/1/CodGrupo_TSP_random_0.7_True_0.01_pmx_12.csv', 'Logs/2/CodGrupo_TSP_random_0.7_True_0.01_pmx_12.csv', 'Logs/3/CodGrupo_TSP_random_0.7_True_0.01_pmx_12.csv', 'Logs/4/CodGrupo_TSP_random_0.7_True_0.01_pmx_12.csv', 'Logs/5/CodGrupo_TSP_random_0.7_True_0.01_pmx_12.csv', 'Logs/6/CodGrupo_TSP_random_0.7_True_0.01_pmx_12.csv', 'Logs/7/CodGrupo_TSP_random_0.7_True_0.01_pmx_12.csv', 'Logs/8/CodGrupo_TSP_random_0.7_True_0.01_pmx_12.csv', 'Logs/9/CodGrupo_TSP_random_0.7_True_0.01_pmx_12.csv']}
# Running config: {'crossover': 'pmx', 'mutation': 'random', 'pmut': 0.01, 'pcross': 0.8, 'elitism': True, 'T': 12}
# {'mutation': 'random', 'crossover': 'pmx', 'pcross': 0.8, 'pmut': 0.01, 'elitism': True, 'T': 12, 'mean': np.float64(9.984094320113194), 'std': np.float64(0.5047580843212778), 'best': np.float64(9.237677733417602), 'time_sec': 376.02972561493516, 'files': ['Logs/0/CodGrupo_TSP_random_0.8_True_0.01_pmx_12.csv', 'Logs/1/CodGrupo_TSP_random_0.8_True_0.01_pmx_12.csv', 'Logs/2/CodGrupo_TSP_random_0.8_True_0.01_pmx_12.csv', 'Logs/3/CodGrupo_TSP_random_0.8_True_0.01_pmx_12.csv', 'Logs/4/CodGrupo_TSP_random_0.8_True_0.01_pmx_12.csv', 'Logs/5/CodGrupo_TSP_random_0.8_True_0.01_pmx_12.csv', 'Logs/6/CodGrupo_TSP_random_0.8_True_0.01_pmx_12.csv', 'Logs/7/CodGrupo_TSP_random_0.8_True_0.01_pmx_12.csv', 'Logs/8/CodGrupo_TSP_random_0.8_True_0.01_pmx_12.csv', 'Logs/9/CodGrupo_TSP_random_0.8_True_0.01_pmx_12.csv']}
# Running config: {'crossover': 'ox', 'mutation': 'random', 'pmut': 0.1, 'pcross': 0.7, 'elitism': True, 'T': 10}
# {'mutation': 'random', 'crossover': 'ox', 'pcross': 0.7, 'pmut': 0.1, 'elitism': True, 'T': 10, 'mean': np.float64(8.18759090306867), 'std': np.float64(0.17330525880072675), 'best': np.float64(7.932136081845388), 'time_sec': 501.6116532199085, 'files': ['Logs/0/CodGrupo_TSP_random_0.7_True_0.1_ox_10.csv', 'Logs/1/CodGrupo_TSP_random_0.7_True_0.1_ox_10.csv', 'Logs/2/CodGrupo_TSP_random_0.7_True_0.1_ox_10.csv', 'Logs/3/CodGrupo_TSP_random_0.7_True_0.1_ox_10.csv', 'Logs/4/CodGrupo_TSP_random_0.7_True_0.1_ox_10.csv', 'Logs/5/CodGrupo_TSP_random_0.7_True_0.1_ox_10.csv', 'Logs/6/CodGrupo_TSP_random_0.7_True_0.1_ox_10.csv', 'Logs/7/CodGrupo_TSP_random_0.7_True_0.1_ox_10.csv', 'Logs/8/CodGrupo_TSP_random_0.7_True_0.1_ox_10.csv', 'Logs/9/CodGrupo_TSP_random_0.7_True_0.1_ox_10.csv']}
# Running config: {'crossover': 'ox', 'mutation': 'random', 'pmut': 0.1, 'pcross': 0.8, 'elitism': True, 'T': 10}
# {'mutation': 'random', 'crossover': 'ox', 'pcross': 0.8, 'pmut': 0.1, 'elitism': True, 'T': 10, 'mean': np.float64(8.327756321805266), 'std': np.float64(0.21689029376578664), 'best': np.float64(8.106932978232026), 'time_sec': 516.0893219728023, 'files': ['Logs/0/CodGrupo_TSP_random_0.8_True_0.1_ox_10.csv', 'Logs/1/CodGrupo_TSP_random_0.8_True_0.1_ox_10.csv', 'Logs/2/CodGrupo_TSP_random_0.8_True_0.1_ox_10.csv', 'Logs/3/CodGrupo_TSP_random_0.8_True_0.1_ox_10.csv', 'Logs/4/CodGrupo_TSP_random_0.8_True_0.1_ox_10.csv', 'Logs/5/CodGrupo_TSP_random_0.8_True_0.1_ox_10.csv', 'Logs/6/CodGrupo_TSP_random_0.8_True_0.1_ox_10.csv', 'Logs/7/CodGrupo_TSP_random_0.8_True_0.1_ox_10.csv', 'Logs/8/CodGrupo_TSP_random_0.8_True_0.1_ox_10.csv', 'Logs/9/CodGrupo_TSP_random_0.8_True_0.1_ox_10.csv']}
# Running config: {'crossover': 'ox', 'mutation': 'random', 'pmut': 0.1, 'pcross': 0.7, 'elitism': True, 'T': 12}
# {'mutation': 'random', 'crossover': 'ox', 'pcross': 0.7, 'pmut': 0.1, 'elitism': True, 'T': 12, 'mean': np.float64(8.382356848056876), 'std': np.float64(0.2267549495181833), 'best': np.float64(7.94013321452226), 'time_sec': 506.50351142697036, 'files': ['Logs/0/CodGrupo_TSP_random_0.7_True_0.1_ox_12.csv', 'Logs/1/CodGrupo_TSP_random_0.7_True_0.1_ox_12.csv', 'Logs/2/CodGrupo_TSP_random_0.7_True_0.1_ox_12.csv', 'Logs/3/CodGrupo_TSP_random_0.7_True_0.1_ox_12.csv', 'Logs/4/CodGrupo_TSP_random_0.7_True_0.1_ox_12.csv', 'Logs/5/CodGrupo_TSP_random_0.7_True_0.1_ox_12.csv', 'Logs/6/CodGrupo_TSP_random_0.7_True_0.1_ox_12.csv', 'Logs/7/CodGrupo_TSP_random_0.7_True_0.1_ox_12.csv', 'Logs/8/CodGrupo_TSP_random_0.7_True_0.1_ox_12.csv', 'Logs/9/CodGrupo_TSP_random_0.7_True_0.1_ox_12.csv']}
# Running config: {'crossover': 'ox', 'mutation': 'random', 'pmut': 0.1, 'pcross': 0.8, 'elitism': True, 'T': 12}
# {'mutation': 'random', 'crossover': 'ox', 'pcross': 0.8, 'pmut': 0.1, 'elitism': True, 'T': 12, 'mean': np.float64(8.276517349797578), 'std': np.float64(0.17046542537624174), 'best': np.float64(7.925966657864133), 'time_sec': 515.1565181370825, 'files': ['Logs/0/CodGrupo_TSP_random_0.8_True_0.1_ox_12.csv', 'Logs/1/CodGrupo_TSP_random_0.8_True_0.1_ox_12.csv', 'Logs/2/CodGrupo_TSP_random_0.8_True_0.1_ox_12.csv', 'Logs/3/CodGrupo_TSP_random_0.8_True_0.1_ox_12.csv', 'Logs/4/CodGrupo_TSP_random_0.8_True_0.1_ox_12.csv', 'Logs/5/CodGrupo_TSP_random_0.8_True_0.1_ox_12.csv', 'Logs/6/CodGrupo_TSP_random_0.8_True_0.1_ox_12.csv', 'Logs/7/CodGrupo_TSP_random_0.8_True_0.1_ox_12.csv', 'Logs/8/CodGrupo_TSP_random_0.8_True_0.1_ox_12.csv', 'Logs/9/CodGrupo_TSP_random_0.8_True_0.1_ox_12.csv']}
# Running config: {'crossover': 'pmx', 'mutation': 'random', 'pmut': 0.1, 'pcross': 0.7, 'elitism': True, 'T': 10}
# {'mutation': 'random', 'crossover': 'pmx', 'pcross': 0.7, 'pmut': 0.1, 'elitism': True, 'T': 10, 'mean': np.float64(8.2922547892633), 'std': np.float64(0.251577245721963), 'best': np.float64(7.863422646091359), 'time_sec': 384.4964094553143, 'files': ['Logs/0/CodGrupo_TSP_random_0.7_True_0.1_pmx_10.csv', 'Logs/1/CodGrupo_TSP_random_0.7_True_0.1_pmx_10.csv', 'Logs/2/CodGrupo_TSP_random_0.7_True_0.1_pmx_10.csv', 'Logs/3/CodGrupo_TSP_random_0.7_True_0.1_pmx_10.csv', 'Logs/4/CodGrupo_TSP_random_0.7_True_0.1_pmx_10.csv', 'Logs/5/CodGrupo_TSP_random_0.7_True_0.1_pmx_10.csv', 'Logs/6/CodGrupo_TSP_random_0.7_True_0.1_pmx_10.csv', 'Logs/7/CodGrupo_TSP_random_0.7_True_0.1_pmx_10.csv', 'Logs/8/CodGrupo_TSP_random_0.7_True_0.1_pmx_10.csv', 'Logs/9/CodGrupo_TSP_random_0.7_True_0.1_pmx_10.csv']}
# Running config: {'crossover': 'pmx', 'mutation': 'random', 'pmut': 0.1, 'pcross': 0.8, 'elitism': True, 'T': 10}
# {'mutation': 'random', 'crossover': 'pmx', 'pcross': 0.8, 'pmut': 0.1, 'elitism': True, 'T': 10, 'mean': np.float64(8.456536320472722), 'std': np.float64(0.3281609055018028), 'best': np.float64(7.784126921122742), 'time_sec': 378.0976866334677, 'files': ['Logs/0/CodGrupo_TSP_random_0.8_True_0.1_pmx_10.csv', 'Logs/1/CodGrupo_TSP_random_0.8_True_0.1_pmx_10.csv', 'Logs/2/CodGrupo_TSP_random_0.8_True_0.1_pmx_10.csv', 'Logs/3/CodGrupo_TSP_random_0.8_True_0.1_pmx_10.csv', 'Logs/4/CodGrupo_TSP_random_0.8_True_0.1_pmx_10.csv', 'Logs/5/CodGrupo_TSP_random_0.8_True_0.1_pmx_10.csv', 'Logs/6/CodGrupo_TSP_random_0.8_True_0.1_pmx_10.csv', 'Logs/7/CodGrupo_TSP_random_0.8_True_0.1_pmx_10.csv', 'Logs/8/CodGrupo_TSP_random_0.8_True_0.1_pmx_10.csv', 'Logs/9/CodGrupo_TSP_random_0.8_True_0.1_pmx_10.csv']}
# Running config: {'crossover': 'pmx', 'mutation': 'random', 'pmut': 0.1, 'pcross': 0.7, 'elitism': True, 'T': 12}
# {'mutation': 'random', 'crossover': 'pmx', 'pcross': 0.7, 'pmut': 0.1, 'elitism': True, 'T': 12, 'mean': np.float64(8.31985090574626), 'std': np.float64(0.16598764752503578), 'best': np.float64(8.084483661611442), 'time_sec': 387.0534536577761, 'files': ['Logs/0/CodGrupo_TSP_random_0.7_True_0.1_pmx_12.csv', 'Logs/1/CodGrupo_TSP_random_0.7_True_0.1_pmx_12.csv', 'Logs/2/CodGrupo_TSP_random_0.7_True_0.1_pmx_12.csv', 'Logs/3/CodGrupo_TSP_random_0.7_True_0.1_pmx_12.csv', 'Logs/4/CodGrupo_TSP_random_0.7_True_0.1_pmx_12.csv', 'Logs/5/CodGrupo_TSP_random_0.7_True_0.1_pmx_12.csv', 'Logs/6/CodGrupo_TSP_random_0.7_True_0.1_pmx_12.csv', 'Logs/7/CodGrupo_TSP_random_0.7_True_0.1_pmx_12.csv', 'Logs/8/CodGrupo_TSP_random_0.7_True_0.1_pmx_12.csv', 'Logs/9/CodGrupo_TSP_random_0.7_True_0.1_pmx_12.csv']}
# Running config: {'crossover': 'pmx', 'mutation': 'random', 'pmut': 0.1, 'pcross': 0.8, 'elitism': True, 'T': 12}
# {'mutation': 'random', 'crossover': 'pmx', 'pcross': 0.8, 'pmut': 0.1, 'elitism': True, 'T': 12, 'mean': np.float64(8.353606552675727), 'std': np.float64(0.17646109752227102), 'best': np.float64(8.074388990821292), 'time_sec': 328.91296201199293, 'files': ['Logs/0/CodGrupo_TSP_random_0.8_True_0.1_pmx_12.csv', 'Logs/1/CodGrupo_TSP_random_0.8_True_0.1_pmx_12.csv', 'Logs/2/CodGrupo_TSP_random_0.8_True_0.1_pmx_12.csv', 'Logs/3/CodGrupo_TSP_random_0.8_True_0.1_pmx_12.csv', 'Logs/4/CodGrupo_TSP_random_0.8_True_0.1_pmx_12.csv', 'Logs/5/CodGrupo_TSP_random_0.8_True_0.1_pmx_12.csv', 'Logs/6/CodGrupo_TSP_random_0.8_True_0.1_pmx_12.csv', 'Logs/7/CodGrupo_TSP_random_0.8_True_0.1_pmx_12.csv', 'Logs/8/CodGrupo_TSP_random_0.8_True_0.1_pmx_12.csv', 'Logs/9/CodGrupo_TSP_random_0.8_True_0.1_pmx_12.csv']}

# %%
# Seleccionar la mejor configuración según la media
best_cfg = min(results, key=lambda x: x["mean"])

print("Mejor configuración encontrada:")
print(best_cfg)

print("\nResultados tras", n_runs * len(configs), "ejecuciones:")

print("Configuración:", best_cfg["files"])
print("Media final:", best_cfg["mean"])
print("Desviación típica:", best_cfg["std"])
print("Mejor valor:", best_cfg["best"])
# Out:
# Mejor configuración encontrada:
# {'mutation': 'inversion', 'crossover': 'ox', 'pcross': 0.8, 'pmut': 0.1, 'elitism': True, 'T': 12, 'mean': np.float64(8.187349641239603), 'std': np.float64(0.19584750183387542), 'best': np.float64(7.828978563829255), 'time_sec': 514.1268867682666, 'files': ['Logs/0/CodGrupo_TSP_inversion_0.8_True_0.1_ox_12.csv', 'Logs/1/CodGrupo_TSP_inversion_0.8_True_0.1_ox_12.csv', 'Logs/2/CodGrupo_TSP_inversion_0.8_True_0.1_ox_12.csv', 'Logs/3/CodGrupo_TSP_inversion_0.8_True_0.1_ox_12.csv', 'Logs/4/CodGrupo_TSP_inversion_0.8_True_0.1_ox_12.csv', 'Logs/5/CodGrupo_TSP_inversion_0.8_True_0.1_ox_12.csv', 'Logs/6/CodGrupo_TSP_inversion_0.8_True_0.1_ox_12.csv', 'Logs/7/CodGrupo_TSP_inversion_0.8_True_0.1_ox_12.csv', 'Logs/8/CodGrupo_TSP_inversion_0.8_True_0.1_ox_12.csv', 'Logs/9/CodGrupo_TSP_inversion_0.8_True_0.1_ox_12.csv']}
#
# Resultados tras 640 ejecuciones:
# Configuración: ['Logs/0/CodGrupo_TSP_inversion_0.8_True_0.1_ox_12.csv', 'Logs/1/CodGrupo_TSP_inversion_0.8_True_0.1_ox_12.csv', 'Logs/2/CodGrupo_TSP_inversion_0.8_True_0.1_ox_12.csv', 'Logs/3/CodGrupo_TSP_inversion_0.8_True_0.1_ox_12.csv', 'Logs/4/CodGrupo_TSP_inversion_0.8_True_0.1_ox_12.csv', 'Logs/5/CodGrupo_TSP_inversion_0.8_True_0.1_ox_12.csv', 'Logs/6/CodGrupo_TSP_inversion_0.8_True_0.1_ox_12.csv', 'Logs/7/CodGrupo_TSP_inversion_0.8_True_0.1_ox_12.csv', 'Logs/8/CodGrupo_TSP_inversion_0.8_True_0.1_ox_12.csv', 'Logs/9/CodGrupo_TSP_inversion_0.8_True_0.1_ox_12.csv']
# Media final: 8.187349641239603
# Desviación típica: 0.19584750183387542
# Mejor valor: 7.828978563829255

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Cargar datos
df = pd.read_csv(best_cfg["files"][0])  # Usar el primer archivo como ejemplo

# Plot
plt.figure()
plt.plot(df["generation"], df["min_fitness"])
plt.xlabel("Generación")
plt.ylabel("Mejor fitness")
plt.title("Convergencia del Algoritmo Genético (TSP)")
plt.grid(True)
plt.show()

# %%
# Seleccionar la mejor configuración según la media
best_cfg = min(results, key=lambda x: x["best"])

print("Mejor configuración encontrada:")
print(best_cfg)

print("\nResultados tras", n_runs * len(configs), "ejecuciones:")

print("Configuración:", best_cfg["files"])
print("Media final:", best_cfg["mean"])
print("Desviación típica:", best_cfg["std"])
print("Mejor valor:", best_cfg["best"])
# Out:
# Mejor configuración encontrada:
# {'mutation': 'random', 'crossover': 'pmx', 'pcross': 0.8, 'pmut': 0.1, 'elitism': True, 'T': 10, 'mean': np.float64(8.456536320472722), 'std': np.float64(0.3281609055018028), 'best': np.float64(7.784126921122742), 'time_sec': 378.0976866334677, 'files': ['Logs/0/CodGrupo_TSP_random_0.8_True_0.1_pmx_10.csv', 'Logs/1/CodGrupo_TSP_random_0.8_True_0.1_pmx_10.csv', 'Logs/2/CodGrupo_TSP_random_0.8_True_0.1_pmx_10.csv', 'Logs/3/CodGrupo_TSP_random_0.8_True_0.1_pmx_10.csv', 'Logs/4/CodGrupo_TSP_random_0.8_True_0.1_pmx_10.csv', 'Logs/5/CodGrupo_TSP_random_0.8_True_0.1_pmx_10.csv', 'Logs/6/CodGrupo_TSP_random_0.8_True_0.1_pmx_10.csv', 'Logs/7/CodGrupo_TSP_random_0.8_True_0.1_pmx_10.csv', 'Logs/8/CodGrupo_TSP_random_0.8_True_0.1_pmx_10.csv', 'Logs/9/CodGrupo_TSP_random_0.8_True_0.1_pmx_10.csv']}
#
# Resultados tras 640 ejecuciones:
# Configuración: ['Logs/0/CodGrupo_TSP_random_0.8_True_0.1_pmx_10.csv', 'Logs/1/CodGrupo_TSP_random_0.8_True_0.1_pmx_10.csv', 'Logs/2/CodGrupo_TSP_random_0.8_True_0.1_pmx_10.csv', 'Logs/3/CodGrupo_TSP_random_0.8_True_0.1_pmx_10.csv', 'Logs/4/CodGrupo_TSP_random_0.8_True_0.1_pmx_10.csv', 'Logs/5/CodGrupo_TSP_random_0.8_True_0.1_pmx_10.csv', 'Logs/6/CodGrupo_TSP_random_0.8_True_0.1_pmx_10.csv', 'Logs/7/CodGrupo_TSP_random_0.8_True_0.1_pmx_10.csv', 'Logs/8/CodGrupo_TSP_random_0.8_True_0.1_pmx_10.csv', 'Logs/9/CodGrupo_TSP_random_0.8_True_0.1_pmx_10.csv']
# Media final: 8.456536320472722
# Desviación típica: 0.3281609055018028
# Mejor valor: 7.784126921122742

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Cargar datos
df = pd.read_csv(best_cfg["files"][0])  # Usar el primer archivo como ejemplo

# Plot
plt.figure()
plt.plot(df["generation"], df["min_fitness"])
plt.xlabel("Generación")
plt.ylabel("Mejor fitness")
plt.title("Convergencia del Algoritmo Genético (TSP)")
plt.grid(True)
plt.show()
