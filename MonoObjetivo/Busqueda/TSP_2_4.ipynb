565554127, 0.07860046445444713], [0.6573938922925594, 0.5023092428939168], [0.2837581848186974, 0.02576704782244421], [0.3044774374252185, 0.7310313422019327], [0.33131673439274434, 0.693896434962478], [0.8523694048117944, 0.2805224723356823], [0.6200019812032047, 0.03989814578273998], [0.5437394088109648, 0.3258031129949792], [0.4386079860370994, 0.6142798815693052], [0.7430581106897977, 0.49260737229959284], [0.3913628378102181, 0.3185830750836698], [0.9065498976196814, 0.02381958527497441], [0.6874236611131453, 0.18642068590773597], [0.6946411585627993, 0.36991609629423117], [0.3784063098306413, 0.01018756575849844], [0.43806374889930155, 0.2268325586117821], [0.7411632641820634, 0.35513151640087337], [0.3884706603234591, 0.34043302784114093], [0.08674110453583683, 0.4491174987265194], [0.9794883193315694, 0.11207520940235804], [0.7496156619797683, 0.23845386610980834], [0.4423888847621813, 0.17212722421686055], [0.2276570035864689, 0.6515924491551327], [0.836939257954547, 0.0499933914625984]] # Length=8.587

def dist (x, y): # distancia euclídea
	return ( (x[0]-y[0])**2 + (x[1]-y[1])**2 ) ** 0.5

def globaldist (cities): # calcula la ditancia global de una solución
	acum = 0.0
	for i in range(len(cities)):
		acum += dist(cities[i-1],cities[i]) # -1 is the last element
	return acum

def fit_cities (cities): # fitness para TSP
	return 1 / (1+globaldist(cities))

# %%
# draw a TSP solution

import matplotlib.pyplot as plt
import numpy as np

def draw (solution):
    plt.ion()
    fig = plt.figure()
    axes = fig.add_subplot(111)
    xlim = axes.set_xlim(0.0,1.0)
    ylim = axes.set_ylim(0.0,1.0)
    x = []
    y = []

    bucle = solution + [solution[0]] # añade al final la vuelta a la primera

    c = np.array(bucle)
    x = c[:,0]
    y = c[:,1]

    l1, = axes.plot(x, y,'g')
    l2, = axes.plot(x, y,'ro')

    s = 'Length=%5.3f' % globaldist(bucle)
    plt.title(s)

draw(cities)

# %% [markdown]
# ## Estudio de parámetros y funciones

# %% [markdown]
# ### Experimento 1: Algoritmo Genético básico

# %% [markdown]
# #### Operaciones básicas

# %% [markdown]
# Se implementan los componentes básicos de inicialización, evaluación y selección del Algoritmo Genético aplicado al TSP. La población inicial se genera de forma aleatoria, donde cada individuo es una permutación del conjunto de ciudades, garantizando diversidad desde la primera generación. Posteriormente, la población se evalúa mediante una función de fitness y se ordena según un criterio de minimización, de manera que los mejores individuos ocupan las primeras posiciones. Sobre esta población ordenada se aplica un mecanismo de selección por torneo, en el que se eligen varios individuos al azar y se selecciona el mejor de ellos, introduciendo presión selectiva sin perder diversidad y asegurando que los individuos seleccionados sean copias independientes

# %%
import random
import copy

def create (alphabet, N=100): # crea y devuelve población
    # Cada individuo es una permutación del alfabeto (p.ej. lista de ciudades)
    pop = []
    for _ in range(N):
        ind = list(alphabet)         # copia
        random.shuffle(ind)          # permutación
        pop.append(ind)
    return pop

def sort_pop(pop, fit):
    fits = [fit(ind) for ind in pop]
    idx = sorted(range(len(pop)), key=lambda i: fits[i])  # minimización
    pop_sorted = [pop[i] for i in idx]
    fits_sorted = [fits[i] for i in idx]
    return pop_sorted, fits_sorted


def select (pop, T): # devuelve un individuo seleccionado por torneo, devuelve una copia para evitar efectos laterales
    # pop se supone ya ordenada por fitness (mejor = pop[0])
    # Torneo: elige T individuos al azar y devuelve el mejor (min fitness)
    best = None
    best_pos = None
    n = len(pop)
    for _ in range(T):
        j = random.randrange(n)
        if (best_pos is None) or (j < best_pos):
            best_pos = j
            best = pop[j]
    return copy.deepcopy(best)

# %% [markdown]
# #### Cruces y mutaciones

# %% [markdown]
# El operador de cruce utilizado en este experimento es **Order Crossover (OX)**, un operador específicamente diseñado para problemas de optimización combinatoria con representación por permutaciones, como el TSP. A diferencia de los cruces clásicos, OX garantiza que los hijos generados sean soluciones factibles, es decir, que cada ciudad aparezca exactamente una vez en la ruta.
#
# El **Partially Mapped Crossover (PMX)** selecciona un segmento de uno de los progenitores y lo copia directamente al descendiente, estableciendo a continuación un mapeo entre los genes intercambiados para completar el resto de la solución sin introducir duplicados. De este modo, el operador preserva información posicional de los padres y garantiza que los individuos generados sean permutaciones válidas.

# %%
def ox_crossover(ind1, ind2, pcross):
    if random.random() > pcross:
        return copy.deepcopy(ind1), copy.deepcopy(ind2)

    L = len(ind1)
    a, b = sorted(random.sample(range(L), 2))

    def key(city):
        return tuple(city) if isinstance(city, list) else city

    def ox(p1, p2):
        child = [None] * L
        child[a:b+1] = copy.deepcopy(p1[a:b+1])
        used = set(key(c) for c in child[a:b+1])

        pos = (b + 1) % L
        for x in p2[b+1:] + p2[:b+1]:
            if key(x) in used:
                continue
            child[pos] = copy.deepcopy(x)
            used.add(key(x))
            pos = (pos + 1) % L

        return child

    return ox(ind1, ind2), ox(ind2, ind1)


def pmx_crossover(ind1, ind2, pcross):
    if random.random() > pcross:
        return copy.deepcopy(ind1), copy.deepcopy(ind2)

    size = len(ind1)
    start, end = sorted(random.sample(range(size), 2))

    child1 = [None] * size
    child2 = [None] * size

    child1[start:end] = copy.deepcopy(ind1[start:end])
    child2[start:end] = copy.deepcopy(ind2[start:end])

    mapping1 = {tuple(ind1[i]): tuple(ind2[i]) for i in range(start, end)}
    mapping2 = {tuple(ind2[i]): tuple(ind1[i]) for i in range(start, end)}

    def fill(child, parent, mapping):
        for i in range(size):
            if child[i] is None:
                gene = tuple(parent[i])
                while gene in mapping:
                    gene = mapping[gene]
                child[i] = list(gene)
        return child

    return fill(child1, ind2, mapping1), fill(child2, ind1, mapping2)

# %% [markdown]
# Se emplea un operador de **swap mutation** (mutate). Conceptualmente, este operador puede interpretarse como una mutación equiprobable por gen, donde cada gen tiene una probabilidad inversamente proporcional a la longitud del cromosoma ($1/L$). La mutación por inversión invierte el orden de un segmento de la ruta, la mutación por mezcla (scramble) reordena aleatoriamente las ciudades de un subsegmento y la mutación aleatoria por permutaciones selecciona de forma estocástica uno de estos operadores

# %%
def mutate (ind, pmut):
    if random.random() > pmut:
        return ind

    L = len(ind)
    i, j = random.sample(range(L), 2)
    ind[i], ind[j] = ind[j], ind[i]
    return ind

def inversion_mutation(ind, pmut):
    if random.random() > pmut:
        return ind
    i, j = sorted(random.sample(range(len(ind)), 2))
    ind[i:j+1] = reversed(ind[i:j+1])
    return ind

def scramble_mutation(ind, pmut):
    if random.random() > pmut:
        return ind
    i, j = sorted(random.sample(range(len(ind)), 2))
    sub = ind[i:j+1]
    random.shuffle(sub)
    ind[i:j+1] = sub
    return ind

def random_perm_mutation(ind, pmut):
    options = [mutate, inversion_mutation, scramble_mutation]
    return random.choice(options)(ind, pmut)

# %% [markdown]
# #### Evaluación
#
# En cada iteración, la población se evalúa y ordena según la función de fitness, se seleccionan individuos mediante torneo y se generan nuevos descendientes aplicando los operadores de cruce y mutación.
#
# La condición de parada del algoritmo se define en términos del número máximo de evaluaciones de la función objetivo $1 M$, tal y como especifica el enunciado. Para ello, se introduce un contador explícito de evaluaciones que se incrementa cada vez que la población es evaluada

# %%
import csv

def evolve(
    pop,
    fit,
    mutation,
    crossover,
    pmut,
    pcross,
    max_evals=1_000_000,
    T=2,
    elitism=False
):
    evals = 0
    gen = 0
    pop_size = len(pop)

    history = []  # (generation, min_fitness)

    while evals < max_evals:
        gen += 1

        pop_sorted, fits_sorted = sort_pop(pop, fit)
        evals += pop_size

        # Guardar mejor fitness de la generación
        history.append((gen, fits_sorted[0]))

        new_pop = []

        if elitism:
            elite = copy.deepcopy(pop_sorted[0])
            new_pop.append(elite)

        while len(new_pop) < pop_size:
            p1 = select(pop_sorted, T)
            p2 = select(pop_sorted, T)

            c1, c2 = crossover(p1, p2, pcross)

            c1 = mutation(c1, pmut)
            new_pop.append(c1)

            if len(new_pop) < pop_size:
                c2 = mutation(c2, pmut)
                new_pop.append(c2)

        pop = new_pop

        # if evals % 1_000 == 0:
        #     print(f"Evals: {evals}, Best fitness: {fits_sorted[0]}")

    pop_sorted, _ = sort_pop(pop, fit)
    return pop_sorted, history

# %% [markdown]
# #### Evolucionamos y pintamos resultados

# %%
mutations = {
    "swap": mutate,
    "inversion": inversion_mutation,
    "scramble": scramble_mutation,
    "random": random_perm_mutation
}

crossovers = {
    "ox": ox_crossover,
    "pmx": pmx_crossover
}

# %% [markdown]
# Se ha tomado la decisión de excluir `"elitism": False` del espacio de búsqueda ya que las pruebas iniciales sugieren que es mejor trabajar con elitismo y añadirlo a la búsqueda incrementa considerablemente el tiempo de ejecución.

# %%
configs = [
    # swap
    {"crossover":"ox", "mutation": "swap", "pmut": 1/100, "pcross": 0.7, "elitism": True, "T": 2},
    {"crossover":"ox", "mutation": "swap", "pmut": 1/100, "pcross": 0.8, "elitism": True, "T": 2},

    {"crossover":"ox", "mutation": "swap", "pmut": 1/100, "pcross": 0.7, "elitism": True, "T": 4},
    {"crossover":"ox", "mutation": "swap", "pmut": 1/100, "pcross": 0.8, "elitism": True, "T": 4},


    {"crossover":"pmx", "mutation": "swap", "pmut": 1/100, "pcross": 0.7, "elitism": True, "T": 2},
    {"crossover":"pmx", "mutation": "swap", "pmut": 1/100, "pcross": 0.8, "elitism": True, "T": 2},

    {"crossover":"pmx", "mutation": "swap", "pmut": 1/100, "pcross": 0.7, "elitism": True, "T": 4},
    {"crossover":"pmx", "mutation": "swap", "pmut": 1/100, "pcross": 0.8, "elitism": True, "T": 4},


    # --------------

    {"crossover":"ox", "mutation": "swap", "pmut": 1/10, "pcross": 0.7, "elitism": True, "T": 2},
    {"crossover":"ox", "mutation": "swap", "pmut": 1/10, "pcross": 0.8, "elitism": True, "T": 2},

    {"crossover":"ox", "mutation": "swap", "pmut": 1/10, "pcross": 0.7, "elitism": True, "T": 4},
    {"crossover":"ox", "mutation": "swap", "pmut": 1/10, "pcross": 0.8, "elitism": True, "T": 4},
    

    {"crossover":"pmx", "mutation": "swap", "pmut": 1/10, "pcross": 0.7, "elitism": True, "T": 2},
    {"crossover":"pmx", "mutation": "swap", "pmut": 1/10, "pcross": 0.8, "elitism": True, "T": 2},

    {"crossover":"pmx", "mutation": "swap", "pmut": 1/10, "pcross": 0.7, "elitism": True, "T": 4},
    {"crossover":"pmx", "mutation": "swap", "pmut": 1/10, "pcross": 0.8, "elitism": True, "T": 4},


    # inversion
    {"crossover":"ox", "mutation": "inversion", "pmut": 1/100, "pcross": 0.7, "elitism": True, "T": 2},
    {"crossover":"ox", "mutation": "inversion", "pmut": 1/100, "pcross": 0.8, "elitism": True, "T": 2},

    {"crossover":"ox", "mutation": "inversion", "pmut": 1/100, "pcross": 0.7, "elitism": True, "T": 4},
    {"crossover":"ox", "mutation": "inversion", "pmut": 1/100, "pcross": 0.8, "elitism": True, "T": 4},


    {"crossover":"pmx", "mutation": "inversion", "pmut": 1/100, "pcross": 0.7, "elitism": True, "T": 2},
    {"crossover":"pmx", "mutation": "inversion", "pmut": 1/100, "pcross": 0.8, "elitism": True, "T": 2},

    {"crossover":"pmx", "mutation": "inversion", "pmut": 1/100, "pcross": 0.7, "elitism": True, "T": 4},
    {"crossover":"pmx", "mutation": "inversion", "pmut": 1/100, "pcross": 0.8, "elitism": True, "T": 4},


    # --------------

    {"crossover":"ox", "mutation": "inversion", "pmut": 1/10, "pcross": 0.7, "elitism": True, "T": 2},
    {"crossover":"ox", "mutation": "inversion", "pmut": 1/10, "pcross": 0.8, "elitism": True, "T": 2},

    {"crossover":"ox", "mutation": "inversion", "pmut": 1/10, "pcross": 0.7, "elitism": True, "T": 4},
    {"crossover":"ox", "mutation": "inversion", "pmut": 1/10, "pcross": 0.8, "elitism": True, "T": 4},

    {"crossover":"pmx", "mutation": "inversion", "pmut": 1/10, "pcross": 0.7, "elitism": True, "T": 2},
    {"crossover":"pmx", "mutation": "inversion", "pmut": 1/10, "pcross": 0.8, "elitism": True, "T": 2},

    {"crossover":"pmx", "mutation": "inversion", "pmut": 1/10, "pcross": 0.7, "elitism": True, "T": 4},
    {"crossover":"pmx", "mutation": "inversion", "pmut": 1/10, "pcross": 0.8, "elitism": True, "T": 4},

    # scramble
    {"crossover":"ox", "mutation": "scramble", "pmut": 1/100, "pcross": 0.7, "elitism": True, "T": 2},
    {"crossover":"ox", "mutation": "scramble", "pmut": 1/100, "pcross": 0.8, "elitism": True, "T": 2},

    {"crossover":"ox", "mutation": "scramble", "pmut": 1/100, "pcross": 0.7, "elitism": True, "T": 4},
    {"crossover":"ox", "mutation": "scramble", "pmut": 1/100, "pcross": 0.8, "elitism": True, "T": 4},


    {"crossover":"pmx", "mutation": "scramble", "pmut": 1/100, "pcross": 0.7, "elitism": True, "T": 2},
    {"crossover":"pmx", "mutation": "scramble", "pmut": 1/100, "pcross": 0.8, "elitism": True, "T": 2},

    {"crossover":"pmx", "mutation": "scramble", "pmut": 1/100, "pcross": 0.7, "elitism": True, "T": 4},
    {"crossover":"pmx", "mutation": "scramble", "pmut": 1/100, "pcross": 0.8, "elitism": True, "T": 4},


    # --------------

    {"crossover":"ox", "mutation": "scramble", "pmut": 1/10, "pcross": 0.7, "elitism": True, "T": 2},
    {"crossover":"ox", "mutation": "scramble", "pmut": 1/10, "pcross": 0.8, "elitism": True, "T": 2},

    {"crossover":"ox", "mutation": "scramble", "pmut": 1/10, "pcross": 0.7, "elitism": True, "T": 4},
    {"crossover":"ox", "mutation": "scramble", "pmut": 1/10, "pcross": 0.8, "elitism": True, "T": 4},


    {"crossover":"pmx", "mutation": "scramble", "pmut": 1/10, "pcross": 0.7, "elitism": True, "T": 2},
    {"crossover":"pmx", "mutation": "scramble", "pmut": 1/10, "pcross": 0.8, "elitism": True, "T": 2},

    {"crossover":"pmx", "mutation": "scramble", "pmut": 1/10, "pcross": 0.7, "elitism": True, "T": 4},
    {"crossover":"pmx", "mutation": "scramble", "pmut": 1/10, "pcross": 0.8, "elitism": True, "T": 4},


    # random
    {"crossover":"ox", "mutation": "random", "pmut": 1/100, "pcross": 0.7, "elitism": True, "T": 2},
    {"crossover":"ox", "mutation": "random", "pmut": 1/100, "pcross": 0.8, "elitism": True, "T": 2},

    {"crossover":"ox", "mutation": "random", "pmut": 1/100, "pcross": 0.7, "elitism": True, "T": 4},
    {"crossover":"ox", "mutation": "random", "pmut": 1/100, "pcross": 0.8, "elitism": True, "T": 4},


    {"crossover":"pmx", "mutation": "random", "pmut": 1/100, "pcross": 0.7, "elitism": True, "T": 2},
    {"crossover":"pmx", "mutation": "random", "pmut": 1/100, "pcross": 0.8, "elitism": True, "T": 2},

    {"crossover":"pmx", "mutation": "random", "pmut": 1/100, "pcross": 0.7, "elitism": True, "T": 4},
    {"crossover":"pmx", "mutation": "random", "pmut": 1/100, "pcross": 0.8, "elitism": True, "T": 4},


    # --------------

    {"crossover":"ox", "mutation": "random", "pmut": 1/10, "pcross": 0.7, "elitism": True, "T": 2},
    {"crossover":"ox", "mutation": "random", "pmut": 1/10, "pcross": 0.8, "elitism": True, "T": 2},

    {"crossover":"ox", "mutation": "random", "pmut": 1/10, "pcross": 0.7, "elitism": True, "T": 4},
    {"crossover":"ox", "mutation": "random", "pmut": 1/10, "pcross": 0.8, "elitism": True, "T": 4},

    {"crossover":"pmx", "mutation": "random", "pmut": 1/10, "pcross": 0.7, "elitism": True, "T": 2},
    {"crossover":"pmx", "mutation": "random", "pmut": 1/10, "pcross": 0.8, "elitism": True, "T": 2},

    {"crossover":"pmx", "mutation": "random", "pmut": 1/10, "pcross": 0.7, "elitism": True, "T": 4},
    {"crossover":"pmx", "mutation": "random", "pmut": 1/10, "pcross": 0.8, "elitism": True, "T": 4},


]

# %%
import os

def run_experiment(cfg, run_id):
    random.seed(None)
    np.random.seed(None)

    pop = create(cities)

    pop, history = evolve(
        pop,
        globaldist,
        mutation=mutations[cfg["mutation"]],
        crossover=crossovers[cfg["crossover"]],
        pmut=cfg["pmut"],
        pcross=cfg["pcross"],
        T=cfg["T"],
        max_evals=1_000_000,
        elitism=cfg["elitism"]
    )

    best_val = globaldist(pop[0])

    folder = f"Logs/{run_id}"
    os.makedirs(folder, exist_ok=True)

    csv_path = (
        f"{folder}/CodGrupo_TSP_"
        f"{cfg['mutation']}_{cfg['pcross']}_{cfg['elitism']}_{cfg['pmut']}_{cfg['crossover']}_{cfg['T']}.csv"
    )

    with open(csv_path, "w", newline="") as f:
        writer = csv.writer(f)
        writer.writerow(["generation", "min_fitness"])
        writer.writerows(history)

    return best_val, csv_path

# %%
from joblib import Parallel, parallel_backend, delayed
import time

n_runs = 10
results = []

for cfg in configs:
    print("Running config:", cfg)

    start = time.perf_counter()

    with parallel_backend("loky", inner_max_num_threads=1):
        out = Parallel(n_jobs=32)(
            delayed(run_experiment)(cfg, i) for i in range(n_runs)
        )

    elapsed = time.perf_counter() - start

    vals = [r[0] for r in out]
    csv_files = [r[1] for r in out]

    results.append({
        "mutation": cfg["mutation"],
        "crossover": cfg["crossover"],
        "pcross": cfg["pcross"],
        "pmut": cfg["pmut"],
        "elitism": cfg["elitism"],
        "T": cfg["T"],
        "mean": np.mean(vals),
        "std": np.std(vals),
        "best": np.min(vals),
        "time_sec": elapsed,
        "files": csv_files
    })

    print(results[-1])
# Out:
# Running config: {'crossover': 'ox', 'mutation': 'swap', 'pmut': 0.01, 'pcross': 0.7, 'elitism': True, 'T': 2}
# {'mutation': 'swap', 'crossover': 'ox', 'pcross': 0.7, 'pmut': 0.01, 'elitism': True, 'T': 2, 'mean': np.float64(10.727780529258167), 'std': np.float64(0.20109759800449487), 'best': np.float64(10.29395315697451), 'time_sec': 498.4251837041229, 'files': ['Logs/0/CodGrupo_TSP_swap_0.7_True_0.01_ox_2.csv', 'Logs/1/CodGrupo_TSP_swap_0.7_True_0.01_ox_2.csv', 'Logs/2/CodGrupo_TSP_swap_0.7_True_0.01_ox_2.csv', 'Logs/3/CodGrupo_TSP_swap_0.7_True_0.01_ox_2.csv', 'Logs/4/CodGrupo_TSP_swap_0.7_True_0.01_ox_2.csv', 'Logs/5/CodGrupo_TSP_swap_0.7_True_0.01_ox_2.csv', 'Logs/6/CodGrupo_TSP_swap_0.7_True_0.01_ox_2.csv', 'Logs/7/CodGrupo_TSP_swap_0.7_True_0.01_ox_2.csv', 'Logs/8/CodGrupo_TSP_swap_0.7_True_0.01_ox_2.csv', 'Logs/9/CodGrupo_TSP_swap_0.7_True_0.01_ox_2.csv']}
# Running config: {'crossover': 'ox', 'mutation': 'swap', 'pmut': 0.01, 'pcross': 0.8, 'elitism': True, 'T': 2}
# {'mutation': 'swap', 'crossover': 'ox', 'pcross': 0.8, 'pmut': 0.01, 'elitism': True, 'T': 2, 'mean': np.float64(10.528257833847473), 'std': np.float64(0.48206202668192993), 'best': np.float64(9.519273570742595), 'time_sec': 510.19670262746513, 'files': ['Logs/0/CodGrupo_TSP_swap_0.8_True_0.01_ox_2.csv', 'Logs/1/CodGrupo_TSP_swap_0.8_True_0.01_ox_2.csv', 'Logs/2/CodGrupo_TSP_swap_0.8_True_0.01_ox_2.csv', 'Logs/3/CodGrupo_TSP_swap_0.8_True_0.01_ox_2.csv', 'Logs/4/CodGrupo_TSP_swap_0.8_True_0.01_ox_2.csv', 'Logs/5/CodGrupo_TSP_swap_0.8_True_0.01_ox_2.csv', 'Logs/6/CodGrupo_TSP_swap_0.8_True_0.01_ox_2.csv', 'Logs/7/CodGrupo_TSP_swap_0.8_True_0.01_ox_2.csv', 'Logs/8/CodGrupo_TSP_swap_0.8_True_0.01_ox_2.csv', 'Logs/9/CodGrupo_TSP_swap_0.8_True_0.01_ox_2.csv']}
# Running config: {'crossover': 'ox', 'mutation': 'swap', 'pmut': 0.01, 'pcross': 0.7, 'elitism': True, 'T': 4}
# {'mutation': 'swap', 'crossover': 'ox', 'pcross': 0.7, 'pmut': 0.01, 'elitism': True, 'T': 4, 'mean': np.float64(12.62659634058104), 'std': np.float64(0.6388625008750858), 'best': np.float64(11.63632751422647), 'time_sec': 502.58790853247046, 'files': ['Logs/0/CodGrupo_TSP_swap_0.7_True_0
 'files': ['Logs/0/CodGrupo_TSP_random_0.7_True_0.01_pmx_4.csv', 'Logs/1/CodGrupo_TSP_random_0.7_True_0.01_pmx_4.csv', 'Logs/2/CodGrupo_TSP_random_0.7_True_0.01_pmx_4.csv', 'Logs/3/CodGrupo_TSP_random_0.7_True_0.01_pmx_4.csv', 'Logs/4/CodGrupo_TSP_random_0.7_True_0.01_pmx_4.csv', 'Logs/5/CodGrupo_TSP_random_0.7_True_0.01_pmx_4.csv', 'Logs/6/CodGrupo_TSP_random_0.7_True_0.01_pmx_4.csv', 'Logs/7/CodGrupo_TSP_random_0.7_True_0.01_pmx_4.csv', 'Logs/8/CodGrupo_TSP_random_0.7_True_0.01_pmx_4.csv', 'Logs/9/CodGrupo_TSP_random_0.7_True_0.01_pmx_4.csv']}
# Running config: {'crossover': 'pmx', 'mutation': 'random', 'pmut': 0.01, 'pcross': 0.8, 'elitism': True, 'T': 4}
# {'mutation': 'random', 'crossover': 'pmx', 'pcross': 0.8, 'pmut': 0.01, 'elitism': True, 'T': 4, 'mean': np.float64(10.022545145456034), 'std': np.float64(0.3866562164708612), 'best': np.float64(9.261900344675809), 'time_sec': 376.6526643708348, 'files': ['Logs/0/CodGrupo_TSP_random_0.8_True_0.01_pmx_4.csv', 'Logs/1/CodGrupo_TSP_random_0.8_True_0.01_pmx_4.csv', 'Logs/2/CodGrupo_TSP_random_0.8_True_0.01_pmx_4.csv', 'Logs/3/CodGrupo_TSP_random_0.8_True_0.01_pmx_4.csv', 'Logs/4/CodGrupo_TSP_random_0.8_True_0.01_pmx_4.csv', 'Logs/5/CodGrupo_TSP_random_0.8_True_0.01_pmx_4.csv', 'Logs/6/CodGrupo_TSP_random_0.8_True_0.01_pmx_4.csv', 'Logs/7/CodGrupo_TSP_random_0.8_True_0.01_pmx_4.csv', 'Logs/8/CodGrupo_TSP_random_0.8_True_0.01_pmx_4.csv', 'Logs/9/CodGrupo_TSP_random_0.8_True_0.01_pmx_4.csv']}
# Running config: {'crossover': 'ox', 'mutation': 'random', 'pmut': 0.1, 'pcross': 0.7, 'elitism': True, 'T': 2}
# {'mutation': 'random', 'crossover': 'ox', 'pcross': 0.7, 'pmut': 0.1, 'elitism': True, 'T': 2, 'mean': np.float64(8.146928144934302), 'std': np.float64(0.2513906710901522), 'best': np.float64(7.840123193222439), 'time_sec': 502.3041775431484, 'files': ['Logs/0/CodGrupo_TSP_random_0.7_True_0.1_ox_2.csv', 'Logs/1/CodGrupo_TSP_random_0.7_True_0.1_ox_2.csv', 'Logs/2/CodGrupo_TSP_random_0.7_True_0.1_ox_2.csv', 'Logs/3/CodGrupo_TSP_random_0.7_True_0.1_ox_2.csv', 'Logs/4/CodGrupo_TSP_random_0.7_True_0.1_ox_2.csv', 'Logs/5/CodGrupo_TSP_random_0.7_True_0.1_ox_2.csv', 'Logs/6/CodGrupo_TSP_random_0.7_True_0.1_ox_2.csv', 'Logs/7/CodGrupo_TSP_random_0.7_True_0.1_ox_2.csv', 'Logs/8/CodGrupo_TSP_random_0.7_True_0.1_ox_2.csv', 'Logs/9/CodGrupo_TSP_random_0.7_True_0.1_ox_2.csv']}
# Running config: {'crossover': 'ox', 'mutation': 'random', 'pmut': 0.1, 'pcross': 0.8, 'elitism': True, 'T': 2}
# {'mutation': 'random', 'crossover': 'ox', 'pcross': 0.8, 'pmut': 0.1, 'elitism': True, 'T': 2, 'mean': np.float64(8.210724348828624), 'std': np.float64(0.21298733467153164), 'best': np.float64(7.7820770159285715), 'time_sec': 510.7337156422436, 'files': ['Logs/0/CodGrupo_TSP_random_0.8_True_0.1_ox_2.csv', 'Logs/1/CodGrupo_TSP_random_0.8_True_0.1_ox_2.csv', 'Logs/2/CodGrupo_TSP_random_0.8_True_0.1_ox_2.csv', 'Logs/3/CodGrupo_TSP_random_0.8_True_0.1_ox_2.csv', 'Logs/4/CodGrupo_TSP_random_0.8_True_0.1_ox_2.csv', 'Logs/5/CodGrupo_TSP_random_0.8_True_0.1_ox_2.csv', 'Logs/6/CodGrupo_TSP_random_0.8_True_0.1_ox_2.csv', 'Logs/7/CodGrupo_TSP_random_0.8_True_0.1_ox_2.csv', 'Logs/8/CodGrupo_TSP_random_0.8_True_0.1_ox_2.csv', 'Logs/9/CodGrupo_TSP_random_0.8_True_0.1_ox_2.csv']}
# Running config: {'crossover': 'ox', 'mutation': 'random', 'pmut': 0.1, 'pcross': 0.7, 'elitism': True, 'T': 4}
# {'mutation': 'random', 'crossover': 'ox', 'pcross': 0.7, 'pmut': 0.1, 'elitism': True, 'T': 4, 'mean': np.float64(8.372240547860047), 'std': np.float64(0.25590790126778895), 'best': np.float64(7.954495897021209), 'time_sec': 501.97038262337446, 'files': ['Logs/0/CodGrupo_TSP_random_0.7_True_0.1_ox_4.csv', 'Logs/1/CodGrupo_TSP_random_0.7_True_0.1_ox_4.csv', 'Logs/2/CodGrupo_TSP_random_0.7_True_0.1_ox_4.csv', 'Logs/3/CodGrupo_TSP_random_0.7_True_0.1_ox_4.csv', 'Logs/4/CodGrupo_TSP_random_0.7_True_0.1_ox_4.csv', 'Logs/5/CodGrupo_TSP_random_0.7_True_0.1_ox_4.csv', 'Logs/6/CodGrupo_TSP_random_0.7_True_0.1_ox_4.csv', 'Logs/7/CodGrupo_TSP_random_0.7_True_0.1_ox_4.csv', 'Logs/8/CodGrupo_TSP_random_0.7_True_0.1_ox_4.csv', 'Logs/9/CodGrupo_TSP_random_0.7_True_0.1_ox_4.csv']}
# Running config: {'crossover': 'ox', 'mutation': 'random', 'pmut': 0.1, 'pcross': 0.8, 'elitism': True, 'T': 4}
# {'mutation': 'random', 'crossover': 'ox', 'pcross': 0.8, 'pmut': 0.1, 'elitism': True, 'T': 4, 'mean': np.float64(8.176327282512997), 'std': np.float64(0.2054475146135553), 'best': np.float64(7.837973788624087), 'time_sec': 514.5706134326756, 'files': ['Logs/0/CodGrupo_TSP_random_0.8_True_0.1_ox_4.csv', 'Logs/1/CodGrupo_TSP_random_0.8_True_0.1_ox_4.csv', 'Logs/2/CodGrupo_TSP_random_0.8_True_0.1_ox_4.csv', 'Logs/3/CodGrupo_TSP_random_0.8_True_0.1_ox_4.csv', 'Logs/4/CodGrupo_TSP_random_0.8_True_0.1_ox_4.csv', 'Logs/5/CodGrupo_TSP_random_0.8_True_0.1_ox_4.csv', 'Logs/6/CodGrupo_TSP_random_0.8_True_0.1_ox_4.csv', 'Logs/7/CodGrupo_TSP_random_0.8_True_0.1_ox_4.csv', 'Logs/8/CodGrupo_TSP_random_0.8_True_0.1_ox_4.csv', 'Logs/9/CodGrupo_TSP_random_0.8_True_0.1_ox_4.csv']}
# Running config: {'crossover': 'pmx', 'mutation': 'random', 'pmut': 0.1, 'pcross': 0.7, 'elitism': True, 'T': 2}
# {'mutation': 'random', 'crossover': 'pmx', 'pcross': 0.7, 'pmut': 0.1, 'elitism': True, 'T': 2, 'mean': np.float64(8.325546944208638), 'std': np.float64(0.2479242736119995), 'best': np.float64(7.998107136084195), 'time_sec': 381.6017710659653, 'files': ['Logs/0/CodGrupo_TSP_random_0.7_True_0.1_pmx_2.csv', 'Logs/1/CodGrupo_TSP_random_0.7_True_0.1_pmx_2.csv', 'Logs/2/CodGrupo_TSP_random_0.7_True_0.1_pmx_2.csv', 'Logs/3/CodGrupo_TSP_random_0.7_True_0.1_pmx_2.csv', 'Logs/4/CodGrupo_TSP_random_0.7_True_0.1_pmx_2.csv', 'Logs/5/CodGrupo_TSP_random_0.7_True_0.1_pmx_2.csv', 'Logs/6/CodGrupo_TSP_random_0.7_True_0.1_pmx_2.csv', 'Logs/7/CodGrupo_TSP_random_0.7_True_0.1_pmx_2.csv', 'Logs/8/CodGrupo_TSP_random_0.7_True_0.1_pmx_2.csv', 'Logs/9/CodGrupo_TSP_random_0.7_True_0.1_pmx_2.csv']}
# Running config: {'crossover': 'pmx', 'mutation': 'random', 'pmut': 0.1, 'pcross': 0.8, 'elitism': True, 'T': 2}
# {'mutation': 'random', 'crossover': 'pmx', 'pcross': 0.8, 'pmut': 0.1, 'elitism': True, 'T': 2, 'mean': np.float64(8.358936118061553), 'std': np.float64(0.2993646053259112), 'best': np.float64(7.991079870500598), 'time_sec': 374.84130227193236, 'files': ['Logs/0/CodGrupo_TSP_random_0.8_True_0.1_pmx_2.csv', 'Logs/1/CodGrupo_TSP_random_0.8_True_0.1_pmx_2.csv', 'Logs/2/CodGrupo_TSP_random_0.8_True_0.1_pmx_2.csv', 'Logs/3/CodGrupo_TSP_random_0.8_True_0.1_pmx_2.csv', 'Logs/4/CodGrupo_TSP_random_0.8_True_0.1_pmx_2.csv', 'Logs/5/CodGrupo_TSP_random_0.8_True_0.1_pmx_2.csv', 'Logs/6/CodGrupo_TSP_random_0.8_True_0.1_pmx_2.csv', 'Logs/7/CodGrupo_TSP_random_0.8_True_0.1_pmx_2.csv', 'Logs/8/CodGrupo_TSP_random_0.8_True_0.1_pmx_2.csv', 'Logs/9/CodGrupo_TSP_random_0.8_True_0.1_pmx_2.csv']}
# Running config: {'crossover': 'pmx', 'mutation': 'random', 'pmut': 0.1, 'pcross': 0.7, 'elitism': True, 'T': 4}
# {'mutation': 'random', 'crossover': 'pmx', 'pcross': 0.7, 'pmut': 0.1, 'elitism': True, 'T': 4, 'mean': np.float64(8.400554821334085), 'std': np.float64(0.15092723758549173), 'best': np.float64(8.183287552120618), 'time_sec': 384.2530416958034, 'files': ['Logs/0/CodGrupo_TSP_random_0.7_True_0.1_pmx_4.csv', 'Logs/1/CodGrupo_TSP_random_0.7_True_0.1_pmx_4.csv', 'Logs/2/CodGrupo_TSP_random_0.7_True_0.1_pmx_4.csv', 'Logs/3/CodGrupo_TSP_random_0.7_True_0.1_pmx_4.csv', 'Logs/4/CodGrupo_TSP_random_0.7_True_0.1_pmx_4.csv', 'Logs/5/CodGrupo_TSP_random_0.7_True_0.1_pmx_4.csv', 'Logs/6/CodGrupo_TSP_random_0.7_True_0.1_pmx_4.csv', 'Logs/7/CodGrupo_TSP_random_0.7_True_0.1_pmx_4.csv', 'Logs/8/CodGrupo_TSP_random_0.7_True_0.1_pmx_4.csv', 'Logs/9/CodGrupo_TSP_random_0.7_True_0.1_pmx_4.csv']}
# Running config: {'crossover': 'pmx', 'mutation': 'random', 'pmut': 0.1, 'pcross': 0.8, 'elitism': True, 'T': 4}
# {'mutation': 'random', 'crossover': 'pmx', 'pcross': 0.8, 'pmut': 0.1, 'elitism': True, 'T': 4, 'mean': np.float64(8.383285305834999), 'std': np.float64(0.19846995619404417), 'best': np.float64(8.04704971466733), 'time_sec': 375.31036540307105, 'files': ['Logs/0/CodGrupo_TSP_random_0.8_True_0.1_pmx_4.csv', 'Logs/1/CodGrupo_TSP_random_0.8_True_0.1_pmx_4.csv', 'Logs/2/CodGrupo_TSP_random_0.8_True_0.1_pmx_4.csv', 'Logs/3/CodGrupo_TSP_random_0.8_True_0.1_pmx_4.csv', 'Logs/4/CodGrupo_TSP_random_0.8_True_0.1_pmx_4.csv', 'Logs/5/CodGrupo_TSP_random_0.8_True_0.1_pmx_4.csv', 'Logs/6/CodGrupo_TSP_random_0.8_True_0.1_pmx_4.csv', 'Logs/7/CodGrupo_TSP_random_0.8_True_0.1_pmx_4.csv', 'Logs/8/CodGrupo_TSP_random_0.8_True_0.1_pmx_4.csv', 'Logs/9/CodGrupo_TSP_random_0.8_True_0.1_pmx_4.csv']}

# %%
# Seleccionar la mejor configuración según la media
best_cfg = min(results, key=lambda x: x["mean"])

print("Mejor configuración encontrada:")
print(best_cfg)

print("\nResultados tras", n_runs * len(configs), "ejecuciones:")

print("Configuración:", best_cfg["files"])
print("Media final:", best_cfg["mean"])
print("Desviación típica:", best_cfg["std"])
print("Mejor valor:", best_cfg["best"])
# Out:
# Mejor configuración encontrada:
# {'mutation': 'inversion', 'crossover': 'ox', 'pcross': 0.7, 'pmut': 0.1, 'elitism': True, 'T': 2, 'mean': np.float64(8.114559605449852), 'std': np.float64(0.13033819361108828), 'best': np.float64(7.850638401374334), 'time_sec': 500.30159705132246, 'files': ['Logs/0/CodGrupo_TSP_inversion_0.7_True_0.1_ox_2.csv', 'Logs/1/CodGrupo_TSP_inversion_0.7_True_0.1_ox_2.csv', 'Logs/2/CodGrupo_TSP_inversion_0.7_True_0.1_ox_2.csv', 'Logs/3/CodGrupo_TSP_inversion_0.7_True_0.1_ox_2.csv', 'Logs/4/CodGrupo_TSP_inversion_0.7_True_0.1_ox_2.csv', 'Logs/5/CodGrupo_TSP_inversion_0.7_True_0.1_ox_2.csv', 'Logs/6/CodGrupo_TSP_inversion_0.7_True_0.1_ox_2.csv', 'Logs/7/CodGrupo_TSP_inversion_0.7_True_0.1_ox_2.csv', 'Logs/8/CodGrupo_TSP_inversion_0.7_True_0.1_ox_2.csv', 'Logs/9/CodGrupo_TSP_inversion_0.7_True_0.1_ox_2.csv']}
#
# Resultados tras 640 ejecuciones:
# Configuración: ['Logs/0/CodGrupo_TSP_inversion_0.7_True_0.1_ox_2.csv', 'Logs/1/CodGrupo_TSP_inversion_0.7_True_0.1_ox_2.csv', 'Logs/2/CodGrupo_TSP_inversion_0.7_True_0.1_ox_2.csv', 'Logs/3/CodGrupo_TSP_inversion_0.7_True_0.1_ox_2.csv', 'Logs/4/CodGrupo_TSP_inversion_0.7_True_0.1_ox_2.csv', 'Logs/5/CodGrupo_TSP_inversion_0.7_True_0.1_ox_2.csv', 'Logs/6/CodGrupo_TSP_inversion_0.7_True_0.1_ox_2.csv', 'Logs/7/CodGrupo_TSP_inversion_0.7_True_0.1_ox_2.csv', 'Logs/8/CodGrupo_TSP_inversion_0.7_True_0.1_ox_2.csv', 'Logs/9/CodGrupo_TSP_inversion_0.7_True_0.1_ox_2.csv']
# Media final: 8.114559605449852
# Desviación típica: 0.13033819361108828
# Mejor valor: 7.850638401374334

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Cargar datos
df = pd.read_csv(best_cfg["files"][0])  # Usar el primer archivo como ejemplo

# Plot
plt.figure()
plt.plot(df["generation"], df["min_fitness"])
plt.xlabel("Generación")
plt.ylabel("Mejor fitness")
plt.title("Convergencia del Algoritmo Genético (TSP)")
plt.grid(True)
plt.show()

# %%
# Seleccionar la mejor configuración según la media
best_cfg = min(results, key=lambda x: x["best"])

print("Mejor configuración encontrada:")
print(best_cfg)

print("\nResultados tras", n_runs * len(configs), "ejecuciones:")

print("Configuración:", best_cfg["files"])
print("Media final:", best_cfg["mean"])
print("Desviación típica:", best_cfg["std"])
print("Mejor valor:", best_cfg["best"])
# Out:
# Mejor configuración encontrada:
# {'mutation': 'random', 'crossover': 'ox', 'pcross': 0.8, 'pmut': 0.1, 'elitism': True, 'T': 2, 'mean': np.float64(8.210724348828624), 'std': np.float64(0.21298733467153164), 'best': np.float64(7.7820770159285715), 'time_sec': 510.7337156422436, 'files': ['Logs/0/CodGrupo_TSP_random_0.8_True_0.1_ox_2.csv', 'Logs/1/CodGrupo_TSP_random_0.8_True_0.1_ox_2.csv', 'Logs/2/CodGrupo_TSP_random_0.8_True_0.1_ox_2.csv', 'Logs/3/CodGrupo_TSP_random_0.8_True_0.1_ox_2.csv', 'Logs/4/CodGrupo_TSP_random_0.8_True_0.1_ox_2.csv', 'Logs/5/CodGrupo_TSP_random_0.8_True_0.1_ox_2.csv', 'Logs/6/CodGrupo_TSP_random_0.8_True_0.1_ox_2.csv', 'Logs/7/CodGrupo_TSP_random_0.8_True_0.1_ox_2.csv', 'Logs/8/CodGrupo_TSP_random_0.8_True_0.1_ox_2.csv', 'Logs/9/CodGrupo_TSP_random_0.8_True_0.1_ox_2.csv']}
#
# Resultados tras 640 ejecuciones:
# Configuración: ['Logs/0/CodGrupo_TSP_random_0.8_True_0.1_ox_2.csv', 'Logs/1/CodGrupo_TSP_random_0.8_True_0.1_ox_2.csv', 'Logs/2/CodGrupo_TSP_random_0.8_True_0.1_ox_2.csv', 'Logs/3/CodGrupo_TSP_random_0.8_True_0.1_ox_2.csv', 'Logs/4/CodGrupo_TSP_random_0.8_True_0.1_ox_2.csv', 'Logs/5/CodGrupo_TSP_random_0.8_True_0.1_ox_2.csv', 'Logs/6/CodGrupo_TSP_random_0.8_True_0.1_ox_2.csv', 'Logs/7/CodGrupo_TSP_random_0.8_True_0.1_ox_2.csv', 'Logs/8/CodGrupo_TSP_random_0.8_True_0.1_ox_2.csv', 'Logs/9/CodGrupo_TSP_random_0.8_True_0.1_ox_2.csv']
# Media final: 8.210724348828624
# Desviación típica: 0.21298733467153164
# Mejor valor: 7.7820770159285715

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Cargar datos
df = pd.read_csv(best_cfg["files"][0])  # Usar el primer archivo como ejemplo

# Plot
plt.figure()
plt.plot(df["generation"], df["min_fitness"])
plt.xlabel("Generación")
plt.ylabel("Mejor fitness")
plt.title("Convergencia del Algoritmo Genético (TSP)")
plt.grid(True)
plt.show()
